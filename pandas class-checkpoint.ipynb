# %% [markdown]
# # ***************************pandas from 1st  day*****************************************

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# fetch data by using Url----sample  API

# %%
p=pd.read_json('https://api.coindesk.com/v1/bpi/currentprice.json')

# %%
p
# Out:
#                                  time  \
# updated      Sep 6, 2023 17:37:00 UTC
# updatedISO  2023-09-06T17:37:00+00:00
# updateduk    Sep 6, 2023 at 18:37 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
p=pd.read_csv(r"C:\ML\missing.csv")   # fetch data from csv file

# %%
p
# Out:
#     id    name   city  aadhar    pan
# 0  101  uddhav  ashti   545.0  12334
# 1  102     ksn    NaN     NaN  53635
# 2  103     sgr    NaN  4534.0    454
# 3  104     sdf    sdf   324.0   3654

# %%
c=pd.read_excel(r'C:\Users\admin\Desktop\f\Data_final_pivot_table.xlsx') # fetch data from excel file

# %%
c
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
c.to_csv('cc.csv',index=False)      #---fetched data dump into csv file

# %%
e=pd.read_csv('cc.csv')

# %%
e['City'][0]
# Out:
# 'kal'

# %%
e['City'][0]='kal'

# %%
################################################################################################################

# %%
e
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,             kal
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
p
# Out:
#     name  age class     mobile
# 0  mohan   12   5th  876543456
# 1   rama   13   6th   98738765
# 2   sham   14   7th  987675432

# %%
p.index=[i for i in range(2000,2003)]

# %%
p
# Out:
#        name  age class     mobile
# 2000  mohan   12   5th  876543456
# 2001   rama   13   6th   98738765
# 2002   sham   14   7th  987675432

# %%
import numpy as np

# %%
ser=pd.Series(np.random.rand(32))

# %%
ser.head()
# Out:
# 0    0.889518
# 1    0.525034
# 2    0.194369
# 3    0.630876
# 4    0.137831
# dtype: float64

# %%
import pandas as pd
import numpy as np

# %%
ser1=pd.DataFrame(np.random.rand(32,5) , index=np.arange(32))

# %%
ser1.head()
# Out:
#           0         1         2         3         4
# 0  0.497496  0.015547  0.748238  0.111711  0.702337
# 1  0.139002  0.970846  0.774050  0.370241  0.959467
# 2  0.212253  0.434018  0.315148  0.933088  0.789961
# 3  0.595644  0.796563  0.341645  0.030871  0.576838
# 4  0.035572  0.300871  0.533971  0.179624  0.165661

# %%
ser1.describe()
# Out:
#                0          1          2          3          4
# count  32.000000  32.000000  32.000000  32.000000  32.000000
# mean    0.487686   0.527839   0.516990   0.460623   0.580276
# std     0.319111   0.324744   0.285118   0.307299   0.243353
# min     0.035572   0.009764   0.039951   0.019006   0.028754
# 25%     0.180207   0.278241   0.291050   0.169904   0.398674
# 50%     0.478311   0.515969   0.494195   0.500864   0.646416
# 75%     0.740642   0.859765   0.776828   0.698180   0.759423
# max     0.993642   0.998427   0.998876   0.962748   0.959467

# %%
ser1.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
ser1[0][0]='Raj'

# %%
type(ser1)
# Out:
# pandas.core.frame.DataFrame

# %%
ser1.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
ser1.head()
# Out:
#           0         1         2         3         4
# 0       Raj  0.586322  0.594573  0.601971  0.486175
# 1  0.086261  0.774752  0.204314  0.484903  0.240002
# 2  0.682058  0.714756  0.107353  0.835281  0.480133
# 3  0.366639  0.312404  0.263439  0.814437  0.412247
# 4  0.528163  0.358649  0.108335  0.012633  0.210828

# %%
new=ser1.to_numpy()

# %%
new
# Out:
# array([['Raj', 0.5863223326191468, 0.5945727544676355, 0.601970943097904,
#         0.486174701754033],
#        [0.0862614497953893, 0.774751608690951, 0.20431362913150108,
#         0.4849030519612514, 0.24000195993512385],
#        [0.6820578874133412, 0.7147564525820548, 0.10735342472836873,
#         0.8352811617214096, 0.4801330351847395],
#        [0.3666394913122504, 0.3124037057665955, 0.26343869666142516,
#         0.8144374711344985, 0.4122473435773837],
#        [0.5281630846365096, 0.35864880913800534, 0.10833472979268266,
#         0.012632776639300292, 0.21082827171910534],
#        [0.47249349769636007, 0.30941053595054724, 0.12882937559988972,
#         0.7018865972680188, 0.5082506177588254],
#        [0.5885794212638352, 0.07060244165390284, 0.06606051632785459,
#         0.9298492977670056, 0.10629385065915586],
#        [0.3270583765651499, 0.715266133176458, 0.4008864391893393,
#         0.02586960883429068, 0.5744824629779356],
# ...

# %%
new.ndim
# Out:
# 2

# %%
Tran=ser1.T  #transpose     r=>col and col=> row

# %%
Tran
# Out:
#          0         1         2         3         4         5         6   \
# 0       Raj    0.3158  0.956753  0.461523  0.862778  0.295514  0.469308
# 1  0.730236  0.962802  0.941093  0.199255  0.034792  0.011859  0.653217
# 2  0.176264  0.224799  0.694191  0.591093  0.593912  0.377561  0.799176
# 3  0.214251  0.583797  0.200614  0.791097  0.684541  0.295984  0.048489
# 4   0.30832  0.237418  0.931731  0.718748  0.157961  0.533431  0.983803
#
#          7         8         9   ...        22        23        24        25  \
# 0  0.248042  0.650941   0.80043  ...  0.693256  0.220411  0.057248   0.31116
# 1  0.567133  0.113395   0.55727  ...  0.302781  0.379182  0.450004  0.784391
# 2  0.194969  0.792852  0.934263  ...  0.056057  0.157814  0.408099  0.627371
# 3   0.93689  0.066476  0.734403  ...  0.157329  0.800485  0.970403   0.68648
# 4  0.891223  0.209428  0.851842  ...  0.864524  0.535314  0.576609  0.921446
#
#          26        27        28        29        30        31
# ...

# %%
descen_index=ser1.sort_index(axis=0, ascending=False)

# %%
descen_index.head()
# Out:
#            0         1         2         3         4
# 31  0.989154  0.982025  0.729665  0.238918  0.733239
# 30  0.520297  0.794637  0.351790  0.824597  0.277765
# 29  0.788783  0.790327  0.807005  0.123834  0.744612
# 28  0.888827  0.069206  0.106717  0.526172  0.693725
# 27  0.015023  0.830781  0.806162  0.809110  0.104292

# %%
descen_col=ser1.sort_index(axis=1, ascending=False)

# %%
descen_col.head()
# Out:
#           4         3         2         1         0
# 0  0.702337  0.111711  0.748238  0.015547  0.497496
# 1  0.959467  0.370241  0.774050  0.970846  0.139002
# 2  0.789961  0.933088  0.315148  0.434018  0.212253
# 3  0.576838  0.030871  0.341645  0.796563  0.595644
# 4  0.165661  0.179624  0.533971  0.300871  0.035572

# %%
descen_col.loc[len(descen_col)]=[0,1,2,3,4]

# %%
descen_col.tail()
# Out:
#             4          3          2          1          0
# 29   0.713297   0.707386   0.818832   0.318571   0.911916
# 30   0.442178   0.064488   0.799202   0.289220   0.993642
# 31   0.287871   0.555349   0.298607   0.245303   0.704166
# 32  44.000000  55.000000  66.000000  77.000000  88.000000
# 33  44.000000  55.000000  66.000000  77.000000  88.000000

# %%
descen_col.loc[32]=[44,55,66,77,88]

# %%
descen_col.columns=list("ABCDE")

# %%
descen_col.head()
# Out:
#           A         B         C         D         E
# 0  0.308320  0.214251  0.176264  0.730236       Raj
# 1  0.237418  0.583797  0.224799  0.962802    0.3158
# 2  0.931731  0.200614  0.694191  0.941093  0.956753
# 3  0.718748  0.791097  0.591093  0.199255  0.461523
# 4  0.157961  0.684541  0.593912  0.034792  0.862778

# %%
descen_col.drop(2 , inplace=True)

# %%
descen_col.head()
# Out:
#           A         B         C         D         E
# 0  0.308320  0.214251  0.176264  0.730236       Raj
# 1  0.237418  0.583797  0.224799  0.962802    0.3158
# 3  0.718748  0.791097  0.591093  0.199255  0.461523
# 4  0.157961  0.684541  0.593912  0.034792  0.862778
# 5  0.533431  0.295984  0.377561  0.011859  0.295514

# %%
descen_col.reset_index(drop=True ,inplace=True)

# %%
descen_col.head()
# Out:
#           A         B         C         D         E
# 0  0.308320  0.214251  0.176264  0.730236       Raj
# 1  0.237418  0.583797  0.224799  0.962802    0.3158
# 2  0.718748  0.791097  0.591093  0.199255  0.461523
# 3  0.157961  0.684541  0.593912  0.034792  0.862778
# 4  0.533431  0.295984  0.377561  0.011859  0.295514

# %%
descen_col['E']=None

# %%
descen_col.head()
# Out:
#           A         B         C         D     E
# 0  0.308320  0.214251  0.176264  0.730236  None
# 1  0.237418  0.583797  0.224799  0.962802  None
# 2  0.718748  0.791097  0.591093  0.199255  None
# 3  0.157961  0.684541  0.593912  0.034792  None
# 4  0.533431  0.295984  0.377561  0.011859  None

# %%
descen_col.dropna(axis=1).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 descen_col.dropna(axis=1).head()
#
# NameError: name 'descen_col' is not defined

# %%
descen_col.drop_duplicates().head()
# Out:
#           4         3         2         1         0
# 0  0.702337  0.111711  0.748238  0.015547  0.497496
# 1  0.959467  0.370241  0.774050  0.970846  0.139002
# 2  0.789961  0.933088  0.315148  0.434018  0.212253
# 3  0.576838  0.030871  0.341645  0.796563  0.595644
# 4  0.165661  0.179624  0.533971  0.300871  0.035572

# %%
descen_col.drop_duplicates(subset=['E'])
# Out:
#          A         B         C         D     E
# 0  0.30832  0.214251  0.176264  0.730236  None

# %%
descen_col.loc[len(descen_col)]=[0.533431,0,0.37756, 0.01185,None]

# %%
descen_col.tail(1)
# Out:
#            A    B        C        D    E
# 32  0.533431  0.0  0.37756  0.01185  NaN

# %%
descen_col=descen_col.drop_duplicates(subset=['A'], keep='first')

# %%
len(descen_col)
# Out:
# 32

# %%
descen_col.drop_duplicates(subset=['E'], keep='last')
# Out:
#            A         B         C         D     E
# 30  0.733239  0.238918  0.729665  0.982025  None
# 32  0.533431  0.000000  0.377560  0.011850   NaN

# %%
ser1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       32 non-null     object
#  1   1       32 non-null     float64
#  2   2       32 non-null     float64
#  3   3       32 non-null     float64
#  4   4       32 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.5+ KB

# %%
ser1.notnull().head()
# Out:
#       0     1     2     3     4
# 0  True  True  True  True  True
# 1  True  True  True  True  True
# 2  True  True  True  True  True
# 3  True  True  True  True  True
# 4  True  True  True  True  True

# %%
#create dataframe using  Dictionary

# %%
o={
    'name':['rama','Mohan'],
    'age':['26','45'],
    'mobile':['98765643','98978654'],
    'class':['1st','2'],
    'sal': ['75000','98765']
    
}

# %%
type(o)
# Out:
# dict

# %%
c=pd.DataFrame(o)

# %%
c
# Out:
#     name age    mobile class    sal
# 0   rama  26  98765643   1st  75000
# 1  Mohan  45  98978654     2  98765

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
################################################################################################

# %%
c
# Out:
#     name age    mobile class    sal
# 0   rama  26  98765643   1st  75000
# 1  Mohan  45  98978654     2  98765

# %%
c.columns             # fetch name of all column
# Out:
# Index(['name', 'age', 'mobile', 'class', 'sal'], dtype='object')

# %%
c.index                 # it is used to fetch no of rows/recods
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
#####################################################################################################

# %%
c.drop('class',axis=1,inplace=True) # drop/ delete perticular column

# %%
c
# Out:
#     name age    mobile    sal
# 0   rama  26  98765643  75000
# 1  Mohan  45  98978654  98765

# %%
c.drop(0)
# Out:
#     name age    mobile    sal
# 1  Mohan  45  98978654  98765

# %%
c
# Out:
#     name age    mobile    sal
# 0   rama  26  98765643  75000
# 1  Mohan  45  98978654  98765

# %%
################################################################################################

# %%
e.head(2)     # fetch records from top
# Out:
#    Client_Code                         Client_Code.1  \
# 0  Client_Code     Essay Infotech Computer Institute
# 1     19210002  Mark Computer Information Technology
#
#                                              Address       City  Taluka  \
# 0             Angel Arc,Shop No.13,Plot No-23,Sec-8,  Kalamboli  Panvel
# 1  1/3, Ashiana Complex, Shivaji Road, Near Hotel...      Mahad   Mahad
#
#   District     Pin Product_Name Area Type        Division  ...  \
# 0   Raigad  410218   Quick heal     Urban  Kokan Division  ...
# 1   Raigad  402301   Quick heal     Urban  Kokan Division  ...
#
#   2021-05-01 00:00:00 2021-06-01 00:00:00 2021-07-01 00:00:00  \
# 0                  14                  25                  26
# 1                  57                   0                  31
#
#   2021-08-01 00:00:00  2021-09-01 00:00:00  2021-10-01 00:00:00  \
# 0                   6                   13                    7
# 1                  10                   16                    0
#
# ...

# %%
e.tail(2)     #  fetch data from bottom
# Out:
#      Client_Code              Client_Code.1  \
# 3300    42210128  SUYASH COMPUTER INSTITUTE
# 3301    42210132   IMAGE COMPUTER EDUCATION
#
#                                                 Address      City    Taluka  \
# 3300  SUYASH SADAN, MAIN ROAD GHATANJI TQ.GHATANJI, ...  GHATANJI  Ghatanji
# 3301       Near Indira Chowk, Halbipura, Kalamb, Kalamb    KALAMB    Kalamb
#
#       District     Pin Product_Name Area Type           Division  ...  \
# 3300  Yavatmal  445301   Quick heal     Urban  Amravati Division  ...
# 3301  Yavatmal  445401   Quick heal     Urban  Amravati Division  ...
#
#      2021-05-01 00:00:00 2021-06-01 00:00:00 2021-07-01 00:00:00  \
# 3300                  25                   0                  12
# 3301                  46                   0                  11
#
#      2021-08-01 00:00:00  2021-09-01 00:00:00  2021-10-01 00:00:00  \
# 3300                   0                    3                    0
# ...

# %%
e.sample(50)        # fetch record dynamicaly
# Out:
#      Client_Code                                      Client_Code.1  \
# 1929    57210085                      Nice Computer Training Centre
# 1199    28210020                          Status Computer Education
# 2156    27210288                                     Excel Infotech
# 3174    32210089                                Gurumauli Computers
# 363     45210142                              Shree Computer Center
# 1011    26210034                                   Pragati Computer
# 3042    12210080                            Shriram Computer Centre
# 3272    42210059                             Igm Computer Education
# 17      19210036                               Collage Of Iit Mahad
# 2911    14210234                                  Computer Concepts
# 616     15210125                                       BK COMPUTERS
# 288     25210045                                Dnyandeep Computers
# 2222    37210001                                    Mitcon E School
# ...

# %%
###########################################################################################################

# %%
e.describe()     #### for high level analysis
# Out:
#                  Pin  2019-01-01 00:00:00  2019-02-01 00:00:00  \
# count    3302.000000          2484.000000          1842.000000
# mean   421728.380073            26.394928            12.598263
# std     13627.317781            24.974651            14.498473
# min    400001.000000             1.000000             1.000000
# 25%    413031.250000            11.000000             4.000000
# 50%    416801.000000            19.000000             8.000000
# 75%    431506.000000            36.000000            15.000000
# max    461721.000000           260.000000           122.000000
#
#        2019-03-01 00:00:00  2019-04-01 00:00:00  2019-06-01 00:00:00  \
# count          2317.000000          3126.000000          2041.000000
# mean             38.672853            69.222009            16.147967
# std              34.820983            63.914428            15.392055
# min               1.000000             1.000000             0.000000
# ...

# %%
#############################################################################################

# %%
#Two methods

# %%
e['City']        ## 1. fetch column by using column name
# Out:
# 0            Kalamboli
# 1                Mahad
# 2               Alibag
# 3             Poladpur
# 4       New Panvel (W)
#              ...
# 3297          Ghatanji
# 3298          yavatmal
# 3299          Maregaon
# 3300          GHATANJI
# 3301            KALAMB
# Name: City, Length: 3302, dtype: object

# %%
e.City         ##2.  fetch column by using column name note: it cant use when space in column name
# Out:
# 0            Kalamboli
# 1                Mahad
# 2               Alibag
# 3             Poladpur
# 4       New Panvel (W)
#              ...
# 3297          Ghatanji
# 3298          yavatmal
# 3299          Maregaon
# 3300          GHATANJI
# 3301            KALAMB
# Name: City, Length: 3302, dtype: object

# %%
e[['City','Taluka']]    ###### it is used for fetching to multiple column
# Out:
#                 City    Taluka
# 0          Kalamboli    Panvel
# 1              Mahad     Mahad
# 2             Alibag    Alibag
# 3           Poladpur  Poladpur
# 4     New Panvel (W)    Panvel
# ...              ...       ...
# 3297        Ghatanji  Ghatanji
# 3298        yavatmal  Yavatmal
# 3299        Maregaon  Maregaon
# 3300        GHATANJI  Ghatanji
# 3301          KALAMB    Kalamb
#
# [3302 rows x 2 columns]

# %%
######################################################################################

# %%
e[[col for col in e.columns if col not in ['District']]]  # fetch  data by excepting  perticular columns
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
##########################################################################################

# %%
# e.rename([])

# %%
e.rename({'location':'location1','Taluka1':'Taluka'},axis=1)   # rename no. of column
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
e.rename({0:'00',1:'01'},axis=0)   # for rename no. of rows by using axis=0
# Out:
#       Client_Code                         Client_Code.1  \
# 00    Client_Code     Essay Infotech Computer Institute
# 01       19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 00               Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 01    1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
e.rename({'location':'location1','Taluka1':'Taluka'},axis=1,inplace=True)   # store changes in same variable then use inplace=True

# %%
e
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
##########################################################################################

# %%
#############---------for Row ------------------------#########################################

# %%
# two methods for rows

# %%
# 1. loc   ---end index inclusive---(include)    # we are not able to use col on the basis of index of col
#2. iloc   ----stop index exclusive---(excluded) # we can acces col by using index

# %%
##### 1. loc   ---end index inclusive---(include)

# %%
# e.loc[rows,col]
#e.loc[2:5,['']]
#e.loc[[2,10,15],['']]
#e.iloc[rows,2:5]
#e.iloc[rows,[2,10,15]]

# %%
e.loc[2:,['Taluka']]     # data from all rows and by showing perticular column
# Out:
#         Taluka
# 2       Alibag
# 3     Poladpur
# 4       Panvel
# 5          Pen
# 6         Roha
# ...        ...
# 3297  Ghatanji
# 3298  Yavatmal
# 3299  Maregaon
# 3300  Ghatanji
# 3301    Kalamb
#
# [3300 rows x 1 columns]

# %%
e.loc[[4,5,7],['location','Taluka1']] #when required perticular rows and perticular column
# Out:
#          location Taluka1
# 4  New Panvel (W)  Panvel
# 5          Raigad     Pen
# 7          Panvel  Panvel

# %%
e.loc[1:1000,['location1','Taluka']]    # when we required range of record e.g: 4 to 6 it is range
# Out:
#            location1    Taluka
# 1              Mahad     Mahad
# 2             Alibag    Alibag
# 3           Poladpur  Poladpur
# 4     New Panvel (W)    Panvel
# 5             Raigad       Pen
# ...              ...       ...
# 996            Jalna     Jalna
# 997            Jalna     Jalna
# 998            Jalna     Jalna
# 999         Jafrabad  Jafrabad
# 1000           Jalna     Jalna
#
# [1000 rows x 2 columns]

# %%
                         ####### iloc   ----stopindex exclusive---(excluded)

# %%
e
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address       location1  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# ...

# %%
e.location1
# Out:
# 0            Kalamboli
# 1                Mahad
# 2               Alibag
# 3             Poladpur
# 4       New Panvel (W)
#              ...
# 3297          Ghatanji
# 3298          yavatmal
# 3299          Maregaon
# 3300          GHATANJI
# 3301            KALAMB
# Name: location1, Length: 3302, dtype: object

# %%
#e.loc[row,column]

# %%
e.loc[[index for index in e.index if index not in [4,5]],['Address','Taluka']]  # to access perticular r
# Out:
#                                                 Address    Taluka
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,    Panvel
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...     Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand    Alibag
# 3     Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sa...  Poladpur
# 6           1 st. Floor, Nirman Plaza, Roha S.T. Stand,      Roha
# ...                                                 ...       ...
# 3297  Paltewar Complex, Near Dr. Puranik Hospital,Ma...  Ghatanji
# 3298  vishal nagar,pipalgaon yawatmal, vishal nagar,...  Yavatmal
# 3299  At Po Maregaon, At Po Maregaon, At Po Maregaon...  Maregaon
# 3300  SUYASH SADAN, MAIN ROAD GHATANJI TQ.GHATANJI, ...  Ghatanji
# 3301       Near Indira Chowk, Halbipura, Kalamb, Kalamb    Kalamb
#
# [3300 rows x 2 columns]

# %%
# iloc ------ integer col location

# %%
e.iloc[[index for index in e.index if index not in [4,5]],3:5]  # fetch  data by excepting  perticular rows
# Out:
#                                                 Address  location1
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,  Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...      Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand     Alibag
# 3     Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sa...   Poladpur
# 6           1 st. Floor, Nirman Plaza, Roha S.T. Stand,       Roha
# ...                                                 ...        ...
# 3297  Paltewar Complex, Near Dr. Puranik Hospital,Ma...   Ghatanji
# 3298  vishal nagar,pipalgaon yawatmal, vishal nagar,...   yavatmal
# 3299  At Po Maregaon, At Po Maregaon, At Po Maregaon...   Maregaon
# 3300  SUYASH SADAN, MAIN ROAD GHATANJI TQ.GHATANJI, ...   GHATANJI
# 3301       Near Indira Chowk, Halbipura, Kalamb, Kalamb     KALAMB
#
# [3300 rows x 2 columns]

# %%
#############################################################################################################

# %%
# --- 21 feb ----------------cant fetch data when system or server off

# %%
pf
# Out:
#                                  time  \
# updated     Apr 30, 2023 14:53:00 UTC
# updatedISO  2023-04-30T14:53:00+00:00
# updateduk   Apr 30, 2023 at 15:53 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
pf=pd.read_json('http://127.0.0.1:8000/API/')  #fetch data from api
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\miniconda3\lib\urllib\request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1345 try:
# -> 1346     h.request(req.get_method(), req.selector, req.data, headers,
#    1347               encode_chunked=req.has_header('Transfer-encoding'))
#    1348 except OSError as err: # timeout error
#
# File ~\miniconda3\lib\http\client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1284 """Send a complete request to the server."""
# -> 1285 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\miniconda3\lib\http\client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
import requests

# %%
requests.get('http://127.0.0.1:8000/API/').json()     #----fetch data by get
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\miniconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\miniconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
######    post data in api    #######
######  <Response [400]> ------for error  
### <Response [201]>    -------proceed

# %%
requests.post('http://127.0.0.1:8000/API/',{'id': 6, 'name':'govind', 'city': 'bepataa', 'sal': 15000})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [92], line 1
# ----> 1 requests.post('http://127.0.0.1:8000/API/',{'id': 6, 'name':'govind', 'city': 'bepataa', 'sal': 15000})
#
# NameError: name 'requests' is not defined

# %%
##########       delete data from API   #########

# %%
requests.delete('http://127.0.0.1:8000/API/update/99')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [94], line 1
# ----> 1 requests.delete('http://127.0.0.1:8000/API/update/99')
#
# NameError: name 'requests' is not defined

# %%
###########################################################################################################################

# %%
e['new column ']='Uddhav'   ###### ******************add new column

# %%
e['column ']= e['Taluka']+'existing'

# %%
e
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %% [markdown]
# # add column of date time

# %%
import datetime
e['date_time']=datetime.datetime.now()

# %%
e
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %% [markdown]
# # modify perticular data from perticular records

# %%
e.loc[2,['location','Taluka1']]=['pune','primpry']   
# note: we cant use index at the place of column

e[(e['location']=='pune') & (e['Taluka']=='Pimpary')]  # for fetch data acording to condition

# %%
e
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address        location  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# ...

# %%
e.loc[[2,4,7],['location1']]=['goa','pune','nagar']

# %%
e.head(10)
# Out:
#    Unnamed: 0  Client_Code                         Client_Code.1  \
# 0           0  Client_Code     Essay Infotech Computer Institute
# 1           1     19210002  Mark Computer Information Technology
# 2           2     19210004         Sharmeen`S Computer Education
# 3           3     19210007                          Om Computers
# 4           4     19210010                     Webtech Computers
# 5           5     19210011               One Up Computer Academy
# 6           6     19210012                        Bits And Bytes
# 7           7     19210014               Sict Computer Education
# 8           8     19210015                    The Apple Computer
# 9           9     19210017              Design Comp-Tech Systems
#
#                                              Address      location1    Taluka  \
# 0             Angel Arc,Shop No.13,Plot No-23,Sec-8,      Kalamboli    Panvel
# 1  1/3, Ashiana Complex, Shivaji Road, Near Hotel...          Mahad     Mahad
# ...

# %% [markdown]
# # delete column/columns

# %%
#  1. delete single column by using drop

# %%
  e.drop('location',axis=1)        # delete single column but for permanent delete from dataframe use inplace=True
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address   Taluka1  District  \
# ...

# %%
e.drop('new column',axis=1,inplace=True)  #for permanent delete from dataframe use inplace=True

# %%
e

# %%
# . delete multi column by using drop

# %%
e.drop(['Address','location1'],axis=1)
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1    Taluka  \
# 0              0  Client_Code     Essay Infotech Computer Institute    Panvel
# 1              1     19210002  Mark Computer Information Technology     Mahad
# 2              2     19210004         Sharmeen`S Computer Education    Alibag
# 3              3     19210007                          Om Computers  Poladpur
# 4              4     19210010                     Webtech Computers    Panvel
# ...          ...          ...                                   ...       ...
# 3297        3297     42210125                     Jalaram Computers  Ghatanji
# 3298        3298     42210126                         sai computers  Yavatmal
# 3299        3299     42210127         Good-Luck Computers, Maregaon  Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE  Ghatanji
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION    Kalamb
#
# ...

# %%
e.columns[[2,8]]
# Out:
# Index(['Address', 'Area Type'], dtype='object')

# %%
e.idmax()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 e.idmax()
#
# NameError: name 'e' is not defined

# %%
e.drop(e.columns[[2,8]],axis=1)
# Out:
#       Client_Code                         Client_Code.1            City  \
# 0     Client_Code     Essay Infotech Computer Institute       Kalamboli
# 1        19210002  Mark Computer Information Technology           Mahad
# 2        19210004         Sharmeen`S Computer Education          Alibag
# 3        19210007                          Om Computers        Poladpur
# 4        19210010                     Webtech Computers  New Panvel (W)
# ...           ...                                   ...             ...
# 3297     42210125                     Jalaram Computers        Ghatanji
# 3298     42210126                         sai computers        yavatmal
# 3299     42210127         Good-Luck Computers, Maregaon        Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE        GHATANJI
# 3301     42210132              IMAGE COMPUTER EDUCATION          KALAMB
#
#         Taluka  District     Pin Product_Name           Division  \
# ...

# %%
e
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address  location1    Taluka  \
# ...

# %% [markdown]
# # Delete or Drop row/rows

# %%
e.drop(0,inplace=True)
# Out:
#       Unnamed: 0  Client_Code                      Client_Code.1  \
# 0              0  Client_Code  Essay Infotech Computer Institute
# 2              2     19210004      Sharmeen`S Computer Education
# 3              3     19210007                       Om Computers
# 4              4     19210010                  Webtech Computers
# 5              5     19210011            One Up Computer Academy
# ...          ...          ...                                ...
# 3297        3297     42210125                  Jalaram Computers
# 3298        3298     42210126                      sai computers
# 3299        3299     42210127      Good-Luck Computers, Maregaon
# 3300        3300     42210128          SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132           IMAGE COMPUTER EDUCATION
#
#                                                 Address   location   Taluka1  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,  Kalamboli    Panvel
# ...

# %%
e.iloc[1:100]
# Out:
#     Unnamed: 0 Client_Code                            Client_Code.1  \
# 1            1    19210002     Mark Computer Information Technology
# 2            2    19210004            Sharmeen`S Computer Education
# 3            3    19210007                             Om Computers
# 4            4    19210010                        Webtech Computers
# 5            5    19210011                  One Up Computer Academy
# ..         ...         ...                                      ...
# 95          95    19210264      E-SPACE COMPUTER TRAINING INSTITUTE
# 96          96    19210276  SHREE GANESHA COMPUTER EDUCATION CENTER
# 97          97    19210278             Powertech Computer Education
# 98          98    19210279  MAHARASHTRA COMPUTER TRAINING INSTITUTE
# 99          99    19210280                  SIDDHIVINAYAK COMPUTERS
#
#                                               Address              location  \
# ...

# %%
e.iloc[1:100]
e[1:100]
# Out:
#     Unnamed: 0 Client_Code                            Client_Code.1  \
# 1            1    19210002     Mark Computer Information Technology
# 2            2    19210004            Sharmeen`S Computer Education
# 3            3    19210007                             Om Computers
# 4            4    19210010                        Webtech Computers
# 5            5    19210011                  One Up Computer Academy
# ..         ...         ...                                      ...
# 95          95    19210264      E-SPACE COMPUTER TRAINING INSTITUTE
# 96          96    19210276  SHREE GANESHA COMPUTER EDUCATION CENTER
# 97          97    19210278             Powertech Computer Education
# 98          98    19210279  MAHARASHTRA COMPUTER TRAINING INSTITUTE
# 99          99    19210280                  SIDDHIVINAYAK COMPUTERS
#
#                                               Address             location1  \
# ...

# %%
e.drop(e.iloc[1:100].index)
# Out:
#       Client_Code                      Client_Code.1  \
# 0     Client_Code  Essay Infotech Computer Institute
# 100      19210281        SIDDHRAJ COMPUTER INSTITUTE
# 101      19210282            Ankur Education Society
# 102      19210283             Shree Ganesh Computers
# 103      19210287   Creative Tech Computer Education
# ...           ...                                ...
# 3297     42210125                  Jalaram Computers
# 3298     42210126                      sai computers
# 3299     42210127      Good-Luck Computers, Maregaon
# 3300     42210128          SUYASH COMPUTER INSTITUTE
# 3301     42210132           IMAGE COMPUTER EDUCATION
#
#                                                 Address              City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,         Kalamboli
# 100   SHOP NO. 10, GROUND FLOOR, SHANTI DARSHAN, OPP...           CHANERE
# 101                    Old Officer's Club, RlL Township         nagothane
# ...

# %%
# delete multiple rows or range of rows

# %%
e.drop([r for r in range(1,3)])    # note: range here exclude type
# Out:
#       Client_Code                      Client_Code.1  \
# 0     Client_Code  Essay Infotech Computer Institute
# 3        19210007                       Om Computers
# 4        19210010                  Webtech Computers
# 5        19210011            One Up Computer Academy
# 6        19210012                     Bits And Bytes
# ...           ...                                ...
# 3297     42210125                  Jalaram Computers
# 3298     42210126                      sai computers
# 3299     42210127      Good-Luck Computers, Maregaon
# 3300     42210128          SUYASH COMPUTER INSTITUTE
# 3301     42210132           IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 3     Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sa...        Poladpur
# 4     120,First Floor, Riddhi Complex, Sector-13, Kh...  New Panvel (W)
# ...

# %%
e.columns
# Out:
# Index(['Unnamed: 0', 'Client_Code', 'Client_Code.1', 'Address', 'location',
#        'Taluka1', 'District', 'Pin', 'Product_Name', 'Area Type', 'Division',
#        'RM_Name', 'Jr.RM_Name', 'DL_Agency_Name', 'TL_Agency_Name',
#        '2019-01-01 00:00:00', '2019-02-01 00:00:00', '2019-03-01 00:00:00',
#        '2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00',
#        '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00',
#        '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00',
#        'Total Sale 2019', 'Total Business in 2019', '2020-01-01 00:00:00',
#        '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00',
#        '2020-05-01 00:00:00', '2020-06-01 00:00:00', '2020-07-01 00:00:00',
#        '2020-08-01 00:00:00', '2020-09-01 00:00:00', '2020-10-01 00:00:00',
#        '2020-11-01 00:00:00', '2020-12-01 00:00:00', 'Total Sale 2020',
# ...

# %% [markdown]
# #  *************** Operation on record's /data***************

# %%
# create a new column by using arithmatic/logical etc

# %%
e['operational_c']=e['location']+'-'+e['Taluka1']

# %%
e['operational_c1']=e['location']+'--'+e['Taluka1']

# %%
e
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address   location   Taluka1  \
# ...

# %%
# 2. fetch unique records

# %%
e['Area Type'].unique() #fetch unique records
# Out:
# array(['Urban', 'Rural', 'rural'], dtype=object)

# %%
# 3. Count perticular data how many times comes in that mentioned column

# %%
e['Area Type'].value_counts()
# Out:
# Urban    2238
# Rural    1063
# rural       1
# Name: Area Type, dtype: int64

# %% [markdown]
# # Filter data or records based on condition

# %%
e[e['Taluka']=='Mahad']     # by condition normal usee '=='
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address  location1 Taluka  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,  Kalamboli  Mahad
# ...

# %%
# for fetching perticular column in specic condition

# %%
e[e['Taluka1']=='Mahad'][['Client_Code','Taluka1']]
# Out:
#     Client_Code Taluka1
# 1      19210002   Mahad
# 17     19210036   Mahad
# 54     19210143   Mahad
# 65     19210158   Mahad
# 84     19210214   Mahad
# 123    19210326   Mahad

# %%
e
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
e.drop(e[e['City']=='Kalamboli'].index)
# e.drop(0,inplace=True)
# 'Unnamed: 0'
# Out:
#      Client_Code                         Client_Code.1  \
# 1       19210002  Mark Computer Information Technology
# 2       19210004         Sharmeen`S Computer Education
# 3       19210007                          Om Computers
# 4       19210010                     Webtech Computers
# 5       19210011               One Up Computer Academy
# ...          ...                                   ...
# 3297    42210125                     Jalaram Computers
# 3298    42210126                         sai computers
# 3299    42210127         Good-Luck Computers, Maregaon
# 3300    42210128             SUYASH COMPUTER INSTITUTE
# 3301    42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# 3     Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sa...        Poladpur
# ...

# %%
e[e['location']=='primpry']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 e[e['location']=='primpry']
#
# NameError: name 'e' is not defined

# %%
e.columns
# Out:
# Index(['Unnamed: 0', 'Client_Code', 'Client_Code.1', 'Address', 'location',
#        'Taluka1', 'District', 'Pin', 'Product_Name', 'Area Type', 'Division',
#        'RM_Name', 'Jr.RM_Name', 'DL_Agency_Name', 'TL_Agency_Name',
#        '2019-01-01 00:00:00', '2019-02-01 00:00:00', '2019-03-01 00:00:00',
#        '2019-04-01 00:00:00', '2019-05-01 00:00:00', '2019-06-01 00:00:00',
#        '2019-07-01 00:00:00', '2019-08-01 00:00:00', '2019-09-01 00:00:00',
#        '2019-10-01 00:00:00', '2019-11-01 00:00:00', '2019-12-01 00:00:00',
#        'Total Sale 2019', 'Total Business in 2019', '2020-01-01 00:00:00',
#        '2020-02-01 00:00:00', '2020-03-01 00:00:00', '2020-04-01 00:00:00',
#        '2020-05-01 00:00:00', '2020-06-01 00:00:00', '2020-07-01 00:00:00',
#        '2020-08-01 00:00:00', '2020-09-01 00:00:00', '2020-10-01 00:00:00',
#        '2020-11-01 00:00:00', '2020-12-01 00:00:00', 'Total Sale 2020',
# ...

# %%
e[e['Taluka1']=='Mahad']
# Out:
#      Unnamed: 0 Client_Code                         Client_Code.1  \
# 1             1    19210002  Mark Computer Information Technology
# 17           17    19210036                  Collage Of Iit Mahad
# 54           54    19210143             Swaraj Computer Institute
# 65           65    19210158             SWARAJ COMPUTER INSTITUTE
# 84           84    19210214               SWARAJ COMPUTER ACADEMY
# 123         123    19210326             OM SAI COMPUTER INSTITUTE
#
#                                                Address location Taluka1  \
# 1    1/3, Ashiana Complex, Shivaji Road, Near Hotel...    Mahad   Mahad
# 17             SHREE ANANT COMPLEX SHIVAJI CHOWK MAHAD    Mahad   Mahad
# 54   At & Post : Nangalwadi, Tal : Mahad, Dist : Ra...    Mahad   Mahad
# 65   AT & POST : BIRWADI,, BABAJI PAWAR COMPLEX, BI...  BIRWADI   Mahad
# 84   OPP. Dr.NAIK HOSPITAL, MALUSARE BUILDING, NEAR...    MAHAD   Mahad
# ...

# %%
e[e['District']=='Raigad'][['Taluka1','Address']]
# Out:
#      Taluka1                                            Address
# 0     Panvel             Angel Arc,Shop No.13,Plot No-23,Sec-8,
# 1      Mahad  1/3, Ashiana Complex, Shivaji Road, Near Hotel...
# 2    primpry          Plot R-14 Shreebaug, No 3, Near Bus Stand
# 4     Panvel  120,First Floor, Riddhi Complex, Sector-13, Kh...
# 5        Pen  ONE UP COMPUTER Shop 9, Near Nagar Palika Stad...
# ..       ...                                                ...
# 122     Tala  First Floor, Above Dhaval Flour Mill, Bazar Pe...
# 123    Mahad      M.G. road juna post. opp vitthal tempal,Mahad
# 124     Roha  A/P GOVE,TATKARE GROUP OF INSTITUTES,NEAR GOVE...
# 125     Tala                Sonar Ali,At-Post-Tala, Taluka-Tala
# 126   Alibag  at - Mandwa Dasturi, Post - Dhokawade, Near - ...
#
# [126 rows x 2 columns]

# %%
e[(e['location']=='Mahad') & (e['District']=='Raigad')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
e[(e['location']=='Mahad') | (e['District']=='Raigad')]   # or condition

# %%
# fetch maximum value from specified column

# %%
e['2021-08-01 00:00:00'].max()
# Out:
# 107

# %%
# fetch minimum value from specified column

# %%
e['2021-08-01 00:00:00'].min()
# Out:
# 0

# %%
# fetch intermediate value from specified column

# %%
e['2021-08-01 00:00:00'].median()
# Out:
# 2.0

# %%
## stand. deviation

# %%
e['2021-08-01 00:00:00'].std()
# Out:
# 9.531281235327672

# %%
######## 22 feb ################################

# %%
e
# Out:
#       Unnamed: 0 Client_Code                         Client_Code.1  \
# 1              1    19210002  Mark Computer Information Technology
# 2              2    19210004         Sharmeen`S Computer Education
# 4              4    19210010                     Webtech Computers
# 5              5    19210011               One Up Computer Academy
# 6              6    19210012                        Bits And Bytes
# ...          ...         ...                                   ...
# 3297        3297    42210125                     Jalaram Computers
# 3298        3298    42210126                         sai computers
# 3299        3299    42210127         Good-Luck Computers, Maregaon
# 3300        3300    42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301    42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address  location   Taluka1  \
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...     Mahad     Mahad
# ...

# %% [markdown]
# ### we can apply to condition by using '&' opperator

# %%
e[(e['2021-07-01 00:00:00']<5)  & (e['location']=='Raigad')]
# Out:
# Empty DataFrame
# ...

# %%
#  max of perticular column with fetching only required column

# %%
e[e['2021-07-01 00:00:00']==e['2021-07-01 00:00:00'].max()][['Client_Code','location']]
# Out:
#      Client_Code location
# 3011    24210085  Pulgaon

# %%
#--------------------------------------------#--------------------------

# %%
q={
    'name':['mohan','ram','krish','udhav','bodke','sagar','renubai'],
    'city':['nanded','kolhapur','kolhapur','pune','nagar','nagar','kjhg'],
    'age':[28,23,26,28,30,26,30],
    'sal':[87654,987654,98767564,8765,876564,87654,87654]
}

# %%
q
# Out:
# {'name': ['mohan', 'ram', 'krish', 'udhav', 'bodke', 'sagar', 'renubai'],
#  'city': ['nanded', 'kolhapur', 'kolhapur', 'pune', 'nagar', 'nagar', 'kjhg'],
#  'age': [28, 23, 26, 28, 30, 26, 30],
#  'sal': [87654, 987654, 98767564, 8765, 876564, 87654, 87654]}

# %%
s = pd.DataFrame(q)

# %%
s
# Out:
#       name      city  age       sal
# 0    mohan    nanded   28     87654
# 1      ram  kolhapur   23    987654
# 2    krish  kolhapur   26  98767564
# 3    udhav      pune   28      8765
# 4    bodke     nagar   30    876564
# 5    sagar     nagar   26     87654
# 6  renubai      kjhg   30     87654

# %%
r={
    'name':['kom','mas','madhu','raj','dev','san','rag'],
    'city':['kolhapur','nagar','pune','nagar','nagar','nagar','pune'],
    'age':[30,23,54,28,55,26,30],
    'sal':[77777777,987654,9000000,8765,876564,10000000,98765432]
}

# %%
r= pd.DataFrame(r)

# %%
r
# Out:
#     name      city  age       sal
# 0    kom  kolhapur   30  77777777
# 1    mas     nagar   23    987654
# 2  madhu      pune   54   9000000
# 3    raj     nagar   28      8765
# 4    dev     nagar   55    876564
# 5    san     nagar   26  10000000
# 6    rag      pune   30  98765432

# %%
# apply perticular condition for rename

# %%
r.loc[0:2,'name']=['raj1','mass','madhukar']
# Out:
# 0        raj1
# 1        mass
# 2    madhukar
# Name: name, dtype: object

# %%
r['name']
# Out:
# 0        raj1
# 1        mass
# 2    madhukar
# 3         raj
# 4         dev
# 5         san
# 6         rag
# Name: name, dtype: object

# %%
r['name']=r['name'].map({'raj1':'raj','mass':'Mohanraj'})  # update

# %%
r
# Out:
#        name      city  age       sal
# 0       raj  kolhapur   30  77777777
# 1  Mohanraj     nagar   23    987654
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000
# 6       NaN      pune   30  98765432

# %%
r.loc[1,'sal']='null'

# %%
def encode(b):
    if type(b) == str:
        return b
    else:
        return 'fill name'

# %%
r['name']=r['name'].apply(encode)

# %%
r
# Out:
#         name      city  age       sal
# 0        raj  kolhapur   30  77777777
# 1   Mohanraj     nagar   23    987654
# 2  fill name      pune   54   9000000
# 3  fill name     nagar   28      8765
# 4  fill name     nagar   55    876564
# 5  fill name     nagar   26  10000000
# 6  fill name      pune   30  98765432

# %%
r['q']=r['name'].apply(lambda X: X if type(X)==str else 'NOT available' )

# %%
r
# Out:
#   name      city  age       sal              q
# 0  NaN  kolhapur   30  77777777  NOT available
# 1  NaN     nagar   23    987654  NOT available
# 2  NaN      pune   54   9000000  NOT available
# 3  NaN     nagar   28      8765  NOT available
# 4  NaN     nagar   55    876564  NOT available
# 5  NaN     nagar   26  10000000  NOT available
# 6  NaN      pune   30  98765432  NOT available

# %%
r['q']=r['name'].map(lambda X: X if type(X)==str else 'Ram' )

# %%
r['new_column']='punna-punna'

# %% [markdown]
# # add row in existing table

# %%
r.loc[len(r)] = ['komraj','kolhapur',30,77777777,'raj','hihi']

# %%
r
# Out:
#      name      city  age       sal    q   new_column
# 0     NaN  kolhapur   30  77777777  Ram  punna-punna
# 1     NaN     nagar   23    987654  Ram  punna-punna
# 2     NaN      pune   54   9000000  Ram  punna-punna
# 3     NaN     nagar   28      8765  Ram  punna-punna
# 4     NaN     nagar   55    876564  Ram  punna-punna
# 5     NaN     nagar   26  10000000  Ram  punna-punna
# 6     NaN      pune   30  98765432  Ram  punna-punna
# 7  komraj  kolhapur   30  77777777  raj         hihi
# 8  komraj  kolhapur   30  77777777  raj         hihi

# %%
# if in table duplicates records and thats duplicate recods wants to delete from table and for permanent change use inplace=true

# %%
r.drop_duplicates()
# Out:
#      name      city  age       sal    q   new_column
# 0     NaN  kolhapur   30  77777777  Ram  punna-punna
# 1     NaN     nagar   23    987654  Ram  punna-punna
# 2     NaN      pune   54   9000000  Ram  punna-punna
# 3     NaN     nagar   28      8765  Ram  punna-punna
# 4     NaN     nagar   55    876564  Ram  punna-punna
# 5     NaN     nagar   26  10000000  Ram  punna-punna
# 6     NaN      pune   30  98765432  Ram  punna-punna
# 7  komraj  kolhapur   30  77777777  raj         hihi

# %%
# map -----usable for one column
# apply ----single or whole table

# %%
r
# Out:
#         name      city  age       sal
# 0        raj  kolhapur   30  77777777
# 1   Mohanraj     nagar   23    987654
# 2  fill name      pune   54   9000000
# 3  fill name     nagar   28      8765
# 4  fill name     nagar   55    876564
# 5  fill name     nagar   26  10000000
# 6  fill name      pune   30  98765432

# %% [markdown]
# ### we can rename of no. of column name at a time

# %%
r.columns=['Name1','City','Age','Sal']

# %%
# r.columns=[]

# %%
r
# Out:
#        Name1      City  Age       Sal
# 0        raj  kolhapur   30  77777777
# 1   Mohanraj     nagar   23    987654
# 2  fill name      pune   54   9000000
# 3  fill name     nagar   28      8765
# 4  fill name     nagar   55    876564
# 5  fill name     nagar   26  10000000
# 6  fill name      pune   30  98765432

# %%
student_data = {
    'stu_name':['sagar','mansi','renuka','krish','Udhav'],
    'marks':[44,34,77,72,99]
}

# %%
stud=pd.DataFrame(student_data)

# %%
stud
# Out:
#   stu_name  marks
# 0    sagar     44
# 1    mansi     34
# 2   renuka     77
# 3    krish     72
# 4    Udhav     99

# %% [markdown]
# #### using encode function we categories to record by condition

# %%
def dd(r):
    if r >= 40:
        return 'Pass'
    else:
        return "Fail"

# %%
stud['status']=stud['marks'].map(dd)

# %%
stud
# Out:
#   stu_name  marks status
# 0    sagar     44   Pass
# 1    mansi     34   Fail
# 2   renuka     77   Pass
# 3    krish     72   Pass
# 4    Udhav     99   Pass

# %%
stud['marks'].unique()
# Out:
# array([44, 34, 77, 72, 99], dtype=int64)

# %%
stud['status']=stud['status'].apply(lambda x: x.split('a')[0])

# %%
stud
# Out:
#   stu_name  marks status
# 0    sagar     44      P
# 1    mansi     34      F
# 2   renuka     77      P
# 3    krish     72      P
# 4    Udhav     99      P

# %%
######################################################################################################################

# %% [markdown]
# # dropna

# %%
##parameter of Dropna(how)     1. any(by default)   2. all

# %%
 #1. any(by default)

# %%
r
# Out:
#        name      city  age       sal              q   new_column
# 0     Mohan  kolhapur   30  77777777          Mohan  punna-punna
# 1  Mohanraj     nagar   23    987654       Mohanraj  punna-punna
# 2       NaN      pune   54   9000000  NOT available  punna-punna
# 3       NaN     nagar   28      8765  NOT available  punna-punna
# 4       NaN     nagar   55    876564  NOT available  punna-punna
# 5       NaN     nagar   26  10000000  NOT available  punna-punna
# 6       NaN      pune   30  98765432  NOT available  punna-punna
# 7    komraj  kolhapur   30  77777777            raj         hihi
# 8    komraj  kolhapur   30  77777777            raj         hihi

# %%
r.dropna()   # drop records even if one is NaN value in that record
# Out:
#        Name1      City  Age       Sal
# 0        raj  kolhapur   30  77777777
# 1   Mohanraj     nagar   23    987654
# 2  fill name      pune   54   9000000
# 3  fill name     nagar   28      8765
# 4  fill name     nagar   55    876564
# 5  fill name     nagar   26  10000000
# 6  fill name      pune   30  98765432

# %%
r.dropna(axis=1)    # drop column even if one is NaN value in that column
# Out:
#        city  age       sal
# 0  kolhapur   30  77777777
# 1     nagar   23      null
# 2      pune   54   9000000
# 3     nagar   28      8765
# 4     nagar   55    876564
# 5     nagar   26  10000000
# 6      pune   30  98765432

# %%
##parameter of Dropna(how)     1. any(by default)   2. all

# %%
r.dropna(how='all')   # drop records even if all are NaN value in that record
# Out:
#      Name      City  Age       Sal update_name update_by_logic
# 0  komraj  kolhapur   30  77777777      komraj          komraj
# 1     NaN     nagar   23       NaN   fill name             Ram
# 2     NaN      pune   54   9000000   fill name             Ram
# 3    raj1     nagar   28      8765        raj1            raj1
# 4     NaN     nagar   55    876564   fill name             Ram
# 5     NaN     nagar   26  10000000   fill name             Ram
# 6     NaN      pune   30  98765432   fill name             Ram
# 7  komraj  kolhapur   30  77777777      komraj          komraj

# %%
r.loc[len(r)] = [None,None,None,None,None,None]

# %%
r
# Out:
#        name      city age       sal              q   new_column
# 0     Mohan  kolhapur  30  77777777          Mohan  punna-punna
# 1  Mohanraj     nagar  23    987654       Mohanraj  punna-punna
# 2       NaN      pune  54   9000000  NOT available  punna-punna
# 3       NaN     nagar  28      8765  NOT available  punna-punna
# 4       NaN     nagar  55    876564  NOT available  punna-punna
# 5       NaN     nagar  26  10000000  NOT available  punna-punna
# 6       NaN      pune  30  98765432  NOT available  punna-punna
# 7    komraj  kolhapur  30  77777777            raj         hihi
# 8
# 9

# %%
 # parameter dropna(how='all')----   2. all

# %%
r.dropna(how='all')
# Out:
#        name      city age       sal              q   new_column
# 0     Mohan  kolhapur  30  77777777          Mohan  punna-punna
# 1  Mohanraj     nagar  23    987654       Mohanraj  punna-punna
# 2       NaN      pune  54   9000000  NOT available  punna-punna
# 3       NaN     nagar  28      8765  NOT available  punna-punna
# 4       NaN     nagar  55    876564  NOT available  punna-punna
# 5       NaN     nagar  26  10000000  NOT available  punna-punna
# 6       NaN      pune  30  98765432  NOT available  punna-punna
# 7    komraj  kolhapur  30  77777777            raj         hihi
# 8
# 9

# %%
r.drop(6)     # delete a row
# Out:
#        name      city  age       sal
# 0     Mohan  kolhapur   30  77777777
# 1  Mohanraj     nagar   23      null
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000

# %%
r
# Out:
#        name      city  age       sal
# 0     Mohan  kolhapur   30  77777777
# 1  Mohanraj     nagar   23      null
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000
# 6       NaN      pune   30  98765432

# %% [markdown]
# #### # parameter dropna(thresh=2)----   # drop records/columns  if thresh value is not equal to value in that record/column

# %%
r.dropna(thresh=3,axis=1)
# Out:
#        Name1      City  Age       Sal
# 0        raj  kolhapur   30  77777777
# 1   Mohanraj     nagar   23    987654
# 2  fill name      pune   54   9000000
# 3  fill name     nagar   28      8765
# 4  fill name     nagar   55    876564
# 5  fill name     nagar   26  10000000
# 6  fill name      pune   30  98765432

# %%
r
# Out:
#        name      city  age       sal
# 0     Mohan  kolhapur   30  77777777
# 1  Mohanraj     nagar   23      null
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000
# 6       NaN      pune   30  98765432

# %%
r.dropna(thresh=1,axis=1)
# Out:
#        name      city  age       sal
# 0     Mohan  kolhapur   30  77777777
# 1  Mohanraj     nagar   23      null
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000
# 6       NaN      pune   30  98765432

# %%
#####################################################################################################################

# %% [markdown]
# # fillna  ---- it used to replace NaN value with required value

# %%
r
# Out:
#        name      city  age       sal
# 0     Mohan  kolhapur   30  77777777
# 1  Mohanraj     nagar   23      null
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000
# 6       NaN      pune   30  98765432

# %%
r.fillna(0)         # replaced all NaN value with 0
# Out:
#        Name1      City  Age       Sal
# 0        raj  kolhapur   30  77777777
# 1   Mohanraj     nagar   23    987654
# 2  fill name      pune   54   9000000
# 3  fill name     nagar   28      8765
# 4  fill name     nagar   55    876564
# 5  fill name     nagar   26  10000000
# 6  fill name      pune   30  98765432

# %%
r
# Out:
#        name      city  age       sal
# 0     Mohan  kolhapur   30  77777777
# 1  Mohanraj     nagar   23      null
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000
# 6       NaN      pune   30  98765432

# %%
r.drop('name',axis=1)
# Out:
#        city  age       sal
# 0  kolhapur   30  77777777
# 1     nagar   23      null
# 2      pune   54   9000000
# 3     nagar   28      8765
# 4     nagar   55    876564
# 5     nagar   26  10000000
# 6      pune   30  98765432

# %%
r
# Out:
#        name      city  age       sal
# 0     Mohan  kolhapur   30  77777777
# 1  Mohanraj     nagar   23      null
# 2       NaN      pune   54   9000000
# 3       NaN     nagar   28      8765
# 4       NaN     nagar   55    876564
# 5       NaN     nagar   26  10000000
# 6       NaN      pune   30  98765432

# %%
r['sub_change']=r['name'].fillna('ram')     # replace NaN values with 'ram'

# %%
r
# Out:
#        Name1      City  Age       Sal
# 0        raj  kolhapur   30  77777777
# 1   Mohanraj     nagar   23    987654
# 2  fill name      pune   54   9000000
# 3  fill name     nagar   28      8765
# 4  fill name     nagar   55    876564
# 5  fill name     nagar   26  10000000
# 6  fill name      pune   30  98765432

# %%
#methods in fillna
#method=ffill
#method=bfill

# %%
r['Name1']=r['Name1'].fillna(method='ffill')

# %%
r
# Out:
#        Name1      City  Age       Sal       name
# 0        raj  kolhapur   30  77777777        raj
# 1   Mohanraj     nagar   23    987654   Mohanraj
# 2  fill name      pune   54   9000000  fill name
# 3  fill name     nagar   28      8765  fill name
# 4  fill name     nagar   55    876564  fill name
# 5  fill name     nagar   26  10000000  fill name
# 6  fill name      pune   30  98765432  fill name

# %%
r['new']=r['name'].fillna(method='bfill')

# %%
r
# Out:
#        Name1      City  Age       Sal       name
# 0        raj  kolhapur   30  77777777        raj
# 1   Mohanraj     nagar   23    987654   Mohanraj
# 2  fill name      pune   54   9000000  fill name
# 3  fill name     nagar   28      8765  fill name
# 4  fill name     nagar   55    876564  fill name
# 5  fill name     nagar   26  10000000  fill name
# 6  fill name      pune   30  98765432  fill name

# %%
################################################################################################################

# %%
## API -----expose means create api 
## API -----consume-means use/call

### api it is also called as 'endponts' because its joint two resources

# %%
########################################################################################################################

# %%
#### groupby condition ##########

# %%
e
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address  location1 Taluka  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,  Kalamboli  Mahad
# ...

# %%
e
# Out:
#       Unnamed: 0  Client_Code                         Client_Code.1  \
# 0              0  Client_Code     Essay Infotech Computer Institute
# 1              1     19210002  Mark Computer Information Technology
# 2              2     19210004         Sharmeen`S Computer Education
# 3              3     19210007                          Om Computers
# 4              4     19210010                     Webtech Computers
# ...          ...          ...                                   ...
# 3297        3297     42210125                     Jalaram Computers
# 3298        3298     42210126                         sai computers
# 3299        3299     42210127         Good-Luck Computers, Maregaon
# 3300        3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301        3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address  location1 Taluka  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,  Kalamboli  Mahad
# ...

# %%
obj=e.groupby('location1') #  its gives in object format it according condition made group

# %%
obj

# %%
obj.get_group('Kalamboli')
# Out:
#     Unnamed: 0  Client_Code                      Client_Code.1  \
# 0            0  Client_Code  Essay Infotech Computer Institute
# 30          30     19210070                     PARAM INFOTECH
# 46          46     19210130          Global Computer Education
# 52          52     19210140            City Computer Education
#
#                                               Address  location1 Taluka  \
# 0              Angel Arc,Shop No.13,Plot No-23,Sec-8,  Kalamboli  Mahad
# 30               KL4/26/1,Sec-4E,Kalamboli,Tal-Panvel  Kalamboli  Mahad
# 46  SHO NO-24,Mahavir Plaza,Plot-11,Sec-5,OPP.HIND...  Kalamboli  Mahad
# 52          LIG 2ND, SEC-2E, SHOP No. H-10, KALAMBOLI  Kalamboli  Mahad
#
#    District     Pin Product_Name Area Type  ... 2021-08-01 00:00:00  \
# 0    Raigad  410218   Quick heal     Urban  ...                   6
# 30   Raigad  410218   Quick heal     Urban  ...                  15
# 46   Raigad  410218   Quick heal     Urban  ...                   6
# ...

# %%
obj.min()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8568\3119354513.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   obj.min()
#                Unnamed: 0 Client_Code  \
# location1
# ADAS                  970    46210304
# ADUL                  738    16210226
# AHMEDPUR              375    45210168
# AJINTHA               763    16210293
# AKOLA                3051    12210098
# ...                   ...         ...
# umapur                978    46210313
# uruli kanchan        2301    47210104
# vaijapur              771    16210315
# wadwani               946    46210245
# yavatmal             3298    42210126
#
#                                            Client_Code.1  \
# location1
# ADAS                        ASARADEVI COMPUTER INSTITUTE
# ADUL                                NEW MAITREE INFOTECH
# ...

# %%
ob=e.groupby('2021-05-01 00:00:00')

# %%
ob.get_group(25).min()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8568\433829235.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ob.get_group(25).min()
# Unnamed: 0                                                  165
# Client_Code                                            13210024
# Client_Code.1                                  ADITYA COMPUTERS
# Address                            "Laxmi Niwas", Near Society,
# location1                                             AMBAJOGAI
# Taluka                                                    Mahad
# District                                             Ahmednagar
# Pin                                                      400012
# Product_Name                                         Quick heal
# ...

# %%
obj.count()
# Out:
#                Unnamed: 0  Client_Code  Client_Code.1  Address  Taluka  \
# location1
# ADAS                    1            1              1        1       1
# ADUL                    1            1              1        1       1
# AHMEDPUR                1            1              1        1       1
# AJINTHA                 1            1              1        1       1
# AKOLA                   5            5              5        5       5
# ...                   ...          ...            ...      ...     ...
# umapur                  1            1              1        1       1
# uruli kanchan           1            1              1        1       1
# vaijapur                1            1              1        1       1
# wadwani                 1            1              1        1       1
# yavatmal                1            1              1        1       1
#
#                District  Pin  Product_Name  Area Type  Division  ...  \
# ...

# %%
###########################################################################

# %% [markdown]
# # concat ######

# %%
U={
    'name':['mohan','ram','krish','seeta','radha'],
    'sal':[87654,765643,65432,7654321,87654321]
    
    
}

# %%
u=pd.DataFrame(U)

# %%
u
# Out:
#     name       sal
# 0  mohan     87654
# 1    ram    765643
# 2  krish     65432
# 3  seeta   7654321
# 4  radha  87654321

# %%
V={
    'name':['udhav','renuka','sagar','gajubhai','krish'],
    'sal':[7777777,888888888,6666666666,999999,555555555]
    
    
}

# %%
v=pd.DataFrame(V)

# %%
v
# Out:
#        name         sal
# 0     udhav     7777777
# 1    renuka   888888888
# 2     sagar  6666666666
# 3  gajubhai      999999
# 4     krish   555555555

# %%
u
# Out:
#     name       sal
# 0  mohan     87654
# 1    ram    765643
# 2  krish     65432
# 3  seeta   7654321
# 4  radha  87654321

# %%
                  #********** this is for same column name ********#

# %%
u_v_concat_same_col=pd.concat([u,v])   # this is for same column name

# %%
u_v_concat_same_col
# Out:
#        name         sal
# 0     mohan       87654
# 1       ram      765643
# 2     krish       65432
# 3     seeta     7654321
# 4     radha    87654321
# 0     udhav     7777777
# 1    renuka   888888888
# 2     sagar  6666666666
# 3  gajubhai      999999
# 4     krish   555555555

# %%
                  #*********  this is for different column name********#

# %%
u_v_concat_diff_col=pd.concat([u,v],axis=1)   # this is for different column name

# %%
u_v_concat_diff_col
# Out:
#     name       sal      name         sal
# 0  mohan     87654     udhav     7777777
# 1    ram    765643    renuka   888888888
# 2  krish     65432     sagar  6666666666
# 3  seeta   7654321  gajubhai      999999
# 4  radha  87654321     krish   555555555

# %%
              #********** if perticular records add**********#

# %%
u_v_perticular=pd.concat([u,v.loc[0:1,:]])

# %%
u_v_perticular
# Out:
#      name        sal
# 0   mohan      87654
# 1     ram     765643
# 2   krish      65432
# 3   seeta    7654321
# 4   radha   87654321
# 0   udhav    7777777
# 1  renuka  888888888

# %%
                    #***********for continue index ***********

# %%
U_v_concat_continue_index=pd.concat([u,v],ignore_index=True)

# %%
U_v_concat_continue_index
# Out:
#        name         sal
# 0     mohan       87654
# 1       ram      765643
# 2     krish       65432
# 3     seeta     7654321
# 4     radha    87654321
# 5     udhav     7777777
# 6    renuka   888888888
# 7     sagar  6666666666
# 8  gajubhai      999999
# 9     krish   555555555

# %%
         #**********concate with dataframe name ************

# %%
u_v_concat_with_dataframe=pd.concat([u,v],keys=['p','v'])

# %%
  # -----it is multi index dataframe

# %%
u_v_concat_with_dataframe
# Out:
#          name         sal
# p 0     mohan       87654
#   1       ram      765643
#   2     krish       65432
#   3     seeta     7654321
#   4     radha    87654321
# v 0     udhav     7777777
#   1    renuka   888888888
#   2     sagar  6666666666
#   3  gajubhai      999999
#   4     krish   555555555

# %%
                #*******fetch perticular records***********#

# %%
u_v_concat_with_dataframe.loc['p'].iloc[1]
# Out:
# name       ram
# sal     765643
# Name: 1, dtype: object

# %%
      #**************reset index***********

# %%
u_v_concat_with_dataframe.reset_index()
# Out:
#   level_0  level_1      name         sal
# 0       p        0     mohan       87654
# 1       p        1       ram      765643
# 2       p        2     krish       65432
# 3       p        3     seeta     7654321
# 4       p        4     radha    87654321
# 5       v        0     udhav     7777777
# 6       v        1    renuka   888888888
# 7       v        2     sagar  6666666666
# 8       v        3  gajubhai      999999
# 9       v        4     krish   555555555

# %%
          #*******How to add new column*********concate with Series

# %%
u
# Out:
#     name       sal
# 0  mohan     87654
# 1    ram    765643
# 2  krish     65432
# 3  seeta   7654321
# 4  radha  87654321

# %%
p=pd.Series([29,22,27,44,33],name='age')

# %%
p
# Out:
# 0    29
# 1    22
# 2    27
# 3    44
# 4    33
# Name: age, dtype: int64

# %%
p_add_column_in_u=pd.concat([u,p],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 p_add_column_in_u=pd.concat([u,p],axis=1)
#
# NameError: name 'u' is not defined

# %%
p_add_column_in_u
# Out:
#     name       sal  age
# 0  mohan     87654   29
# 1    ram    765643   22
# 2  krish     65432   27
# 3  seeta   7654321   44
# 4  radha  87654321   33

# %%
#######################################################################

# %% [markdown]
# # Merge #

# %%
#normalisation
# for merging - there should be common a column

# %%
c={
    'id':[1,2,3,4],
    'name':['mohan','ram','sham','udhav']
}

# %%
c=pd.DataFrame(c)

# %%
c
# Out:
#    id   name
# 0   1  mohan
# 1   2    ram
# 2   3   sham
# 3   4  udhav

# %%
d={
    'id':[1,2,3,4],
    'sal':[8765432,87654,987654,987654]
}

# %%
d=pd.DataFrame(d)

# %%
d
# Out:
#    id      sal
# 0   1  8765432
# 1   2    87654
# 2   3   987654
# 3   4   987654

# %%
c
# Out:
#    id   name
# 0   1  mohan
# 1   2    ram
# 2   3   sham
# 3   4  udhav

# %%
d
# Out:
#    id      sal
# 0   1  8765432
# 1   2    87654
# 2   3   987654
# 3   4   987654

# %%
    #************* by inner join ---fetch common records and join

# %%
e=pd.merge(c,d,on='id',how='inner')  
e=pd.join(c,d,on='id',how='inner') # ----- we can also go through it

# %%
e
# Out:
#    id   name      sal
# 0   1  mohan  8765432
# 1   2    ram    87654
# 2   3   sham   987654
# 3   4  udhav   987654

# %%
f={
    'id':[3,4],
    'sal':[9897654,7654]
}

# %%
f=pd.DataFrame(f)

# %%
f
# Out:
#    id      sal
# 0   3  9897654
# 1   4     7654

# %%
c
# Out:
#    id   name
# 0   1  mohan
# 1   2    ram
# 2   3   sham
# 3   4  udhav

# %%
 #************* by  left  ---fetch all left side records
    #with common right side records as per common column and join**********

# %%
g=pd.merge(c,f,on='id',how='inner')

# %%
g
# Out:
#    id   name      sal
# 0   3   sham  9897654
# 1   4  udhav     7654

# %%
h=pd.merge(c,f,on='id',how='left')

# %%
h
# Out:
#    id   name        sal
# 0   1  mohan        NaN
# 1   2    ram        NaN
# 2   3   sham  9897654.0
# 3   4  udhav     7654.0

# %%
 #************* by  right  ---fetch all right side records
    #with common left side records as per common column and join**********

# %%
i=pd.merge(c,f,on='id',how='right')

# %%
i
# Out:
#    id   name      sal
# 0   3   sham  9897654
# 1   4  udhav     7654

# %%
   #******for both matched or unmatched records**************

# %%
j=pd.merge(c,f,on='id',how='outer')

# %%
j
# Out:
#    id   name        sal
# 0   1  mohan        NaN
# 1   2    ram        NaN
# 2   3   sham  9897654.0
# 3   4  udhav     7654.0

# %%
########################################################################

# %% [markdown]
# ####change data type  of df column

# %%
e
# Out:
#    id   name      sal
# 0   1  mohan  8765432
# 1   2    ram    87654
# 2   3   sham   987654
# 3   4  udhav   987654

# %%
e.dtypes
# Out:
# id       int64
# name    object
# sal      int64
# dtype: object

# %%
e['sal']=e['sal'].astype('int64')

# %%
e.dtypes
# Out:
# id       int64
# name    object
# sal      int64
# dtype: object

# %%
###########################################################

# %%
#******* fetch integer values from given string*****************

# %%
e['gg']=e['name']+'987654'

# %%
e
# Out:
#    id   name      sal           gg
# 0   1  mohan  8765432  mohan987654
# 1   2    ram    87654    ram987654
# 2   3   sham   987654   sham987654
# 3   4  udhav   987654  udhav987654

# %%
import re
re.findall(r'\d+', "hello 42 I'm ,a 32 string 30")
# Out:
# ['42', '32', '30']

# %%
e['gg'].map(lambda x: re.findall(r'\d+', x))
# Out:
# 0    [987654]
# 1    [987654]
# 2    [987654]
# 3    [987654]
# Name: gg, dtype: object

# %%
##############################################################

# %%
r
# Out:
#        name      city age       sal              q   new_column sub_change  \
# 0     Mohan  kolhapur  30  77777777          Mohan  punna-punna      Mohan
# 1  Mohanraj     nagar  23    987654       Mohanraj  punna-punna   Mohanraj
# 2       NaN      pune  54   9000000  NOT available  punna-punna        ram
# 3       NaN     nagar  28      8765  NOT available  punna-punna        ram
# 4       NaN     nagar  55    876564  NOT available  punna-punna        ram
# 5       NaN     nagar  26  10000000  NOT available  punna-punna        ram
# 6       NaN      pune  30  98765432  NOT available  punna-punna        ram
# 7    komraj  kolhapur  30  77777777            raj         hihi     komraj
#
#         Sal     kjkgh
# 0  77777777  77777777
# 1    987654    987654
# 2   9000000   9000000
# 3      8765      8765
# 4    876564    876564
# 5  10000000  10000000
# 6  98765432  98765432
# 7  77777777  77777777

# %%
r.rename(columns=str.lower)
# Out:
#        name1      city  age       sal       name
# 0        raj  kolhapur   30  77777777        raj
# 1   Mohanraj     nagar   23    987654   Mohanraj
# 2  fill name      pune   54   9000000  fill name
# 3  fill name     nagar   28      8765  fill name
# 4  fill name     nagar   55    876564  fill name
# 5  fill name     nagar   26  10000000  fill name
# 6  fill name      pune   30  98765432  fill name

# %%
############################--End Pandas--######################################

# %%
u_v_concat_diff_col=pd.concat([u,f],axis=1)

# %%
u_v_concat_diff_col
# Out:
#     name       sal   id        sal
# 0  mohan     87654  3.0  9897654.0
# 1    ram    765643  4.0     7654.0
# 2  krish     65432  NaN        NaN
# 3  seeta   7654321  NaN        NaN
# 4  radha  87654321  NaN        NaN

# %%
f
# Out:
#    id      sal
# 0   3  9897654
# 1   4     7654

# %%
#Interview questions

# %%
pf=pd.read_json('https://api.coindesk.com/v1/bpi/currentprice.json')

# %%
pf
# Out:
#                                  time  \
# updated     May 13, 2023 15:22:00 UTC
# updatedISO  2023-05-13T15:22:00+00:00
# updateduk   May 13, 2023 at 16:22 BST
# USD                               NaN
# GBP                               NaN
# EUR                               NaN
#
#                                                    disclaimer chartName  \
# updated     This data was produced from the CoinDesk Bitco...   Bitcoin
# updatedISO  This data was produced from the CoinDesk Bitco...   Bitcoin
# updateduk   This data was produced from the CoinDesk Bitco...   Bitcoin
# USD         This data was produced from the CoinDesk Bitco...   Bitcoin
# GBP         This data was produced from the CoinDesk Bitco...   Bitcoin
# EUR         This data was produced from the CoinDesk Bitco...   Bitcoin
#
#                                                           bpi
# updated                                                   NaN
# updatedISO                                                NaN
# ...

# %%
c=pd.read_excel(r'C:\Users\admin\Desktop\Data_final_pivot_table.xlsx')

# %%
c
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
c['new']=c['Taluka']+c['District']

# %%
c
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
ob=c.groupby('Total Business in 2021')

# %%
ob.get_group(25000).count()
# Out:
# Client_Code               52
# Client_Code.1             52
# Address                   52
# City                      52
# Taluka                    52
# District                  52
# Pin                       52
# Product_Name              52
# Area Type                 52
# Division                  52
# RM_Name                   52
# Jr.RM_Name                52
# DL_Agency_Name            52
# TL_Agency_Name            52
# 2019-01-01 00:00:00       41
# 2019-02-01 00:00:00       27
# 2019-03-01 00:00:00       28
# 2019-04-01 00:00:00       51
# 2019-05-01 00:00:00       42
# 2019-06-01 00:00:00       29
# 2019-07-01 00:00:00       43
# 2019-08-01 00:00:00       43
# 2019-09-01 00:00:00       41
# 2019-10-01 00:00:00       52
# 2019-11-01 00:00:00       52
# 2019-12-01 00:00:00       41
# Total Sale 2019           52
# Total Business in 2019    52
# 2020-01-01 00:00:00       52
# 2020-02-01 00:00:00       52
# 2020-03-01 00:00:00       52
# 2020-04-01 00:00:00       52
# ...

# %%
c
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
c.dropna(inplace=True,)

# %%
c
# Out:
#      Client_Code                         Client_Code.1  \
# 1       19210002  Mark Computer Information Technology
# 4       19210010                     Webtech Computers
# 6       19210012                        Bits And Bytes
# 7       19210014               Sict Computer Education
# 8       19210015                    The Apple Computer
# ...          ...                                   ...
# 3293    42210114                 Maharashtra Computers
# 3294    42210118           Swami vivekananda computech
# 3295    42210120   Shree Chintamani Computers Ralegaon
# 3297    42210125                     Jalaram Computers
# 3301    42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 4     120,First Floor, Riddhi Complex, Sector-13, Kh...  New Panvel (W)
# 6           1 st. Floor, Nirman Plaza, Roha S.T. Stand,            Roha
# ...

# %%
c.columns
# Out:
# Index([           'Client_Code',          'Client_Code.1',
#                       'Address',                   'City',
#                        'Taluka',               'District',
#                           'Pin',           'Product_Name',
#                     'Area Type',               'Division',
#                       'RM_Name',             'Jr.RM_Name',
#                'DL_Agency_Name',         'TL_Agency_Name',
#             2019-01-01 00:00:00,      2019-02-01 00:00:00,
#             2019-03-01 00:00:00,      2019-04-01 00:00:00,
#             2019-05-01 00:00:00,      2019-06-01 00:00:00,
#             2019-07-01 00:00:00,      2019-08-01 00:00:00,
#             2019-09-01 00:00:00,      2019-10-01 00:00:00,
#             2019-11-01 00:00:00,      2019-12-01 00:00:00,
#               'Total Sale 2019', 'Total Business in 2019',
#             2020-01-01 00:00:00,      2020-02-01 00:00:00,
#             2020-03-01 00:00:00,      2020-04-01 00:00:00,
# ...

# %%
c.index
# Out:
# Int64Index([   1,    4,    6,    7,    8,   10,   17,   23,   36,   43,
#             ...
#             3281, 3282, 3283, 3285, 3292, 3293, 3294, 3295, 3297, 3301],
#            dtype='int64', length=719)

# %%
p=['34nhn','jhjgfd4534433','gfdgs633']
import re
for i in p:
    c=re.findall(r'\d+',i)
    print(c)
# Out:
# ['34']
# ['4534433']
# ['633']

# %%
###########################################################################
# data structure in pandas
# 1. Series and DataFrame


# features of pandas
   # memory Efficient
   # time series
   # Reshaping
   # Data Alignment
   # Merge and join

# %%
c
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
c.info
# Out:
# <bound method DataFrame.info of       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# ...

# %%
c.size
# Out:
# 184912

# %%
c.shape
# Out:
# (3302, 56)

# %%
c.describe()
# Out:
#                  Pin  2019-01-01 00:00:00  2019-02-01 00:00:00  \
# count    3302.000000          2484.000000          1842.000000
# mean   421728.380073            26.394928            12.598263
# std     13627.317781            24.974651            14.498473
# min    400001.000000             1.000000             1.000000
# 25%    413031.250000            11.000000             4.000000
# 50%    416801.000000            19.000000             8.000000
# 75%    431506.000000            36.000000            15.000000
# max    461721.000000           260.000000           122.000000
#
#        2019-03-01 00:00:00  2019-04-01 00:00:00  2019-06-01 00:00:00  \
# count          2317.000000          3126.000000          2041.000000
# mean             38.672853            69.222009            16.147967
# std              34.820983            63.914428            15.392055
# min               1.000000             1.000000             0.000000
# ...

# %%
c.describe().T
# Out:
#                          count           mean           std       min  \
# Pin                     3302.0  421728.380073  13627.317781  400001.0
# 2019-01-01 00:00:00     2484.0      26.394928     24.974651       1.0
# 2019-02-01 00:00:00     1842.0      12.598263     14.498473       1.0
# 2019-03-01 00:00:00     2317.0      38.672853     34.820983       1.0
# 2019-04-01 00:00:00     3126.0      69.222009     63.914428       1.0
# 2019-06-01 00:00:00     2041.0      16.147967     15.392055       0.0
# 2019-07-01 00:00:00     2816.0      17.372869     16.551556       0.0
# 2019-08-01 00:00:00     2766.0      12.721258     14.718775       0.0
# 2019-09-01 00:00:00     2645.0      10.786767     11.896740       0.0
# 2019-10-01 00:00:00     3302.0      11.944579     13.135198       0.0
# 2019-11-01 00:00:00     3302.0       5.317383      8.134238       0.0
# 2019-12-01 00:00:00     2848.0      16.613413     15.818466       0.0
# ...

# %%
c.nunique()   # --
# Out:
# Client_Code               3302
# Client_Code.1             2759
# Address                   3293
# City                      1450
# Taluka                     345
# District                    39
# Pin                       1069
# Product_Name                 2
# Area Type                    3
# Division                     6
# RM_Name                      6
# Jr.RM_Name                   8
# DL_Agency_Name              32
# TL_Agency_Name             388
# 2019-01-01 00:00:00         92
# 2019-02-01 00:00:00         52
# 2019-03-01 00:00:00        107
# 2019-04-01 00:00:00        191
# 2019-05-01 00:00:00         81
# 2019-06-01 00:00:00         65
# 2019-07-01 00:00:00         73
# 2019-08-01 00:00:00         61
# 2019-09-01 00:00:00         47
# 2019-10-01 00:00:00         60
# 2019-11-01 00:00:00         44
# 2019-12-01 00:00:00         61
# Total Sale 2019            353
# Total Business in 2019     353
# 2020-01-01 00:00:00        103
# 2020-02-01 00:00:00         61
# ...

# %%
c.isna().any()
# Out:
# Client_Code               False
# Client_Code.1             False
# Address                   False
# City                       True
# Taluka                    False
# District                  False
# Pin                       False
# Product_Name              False
# Area Type                 False
# Division                  False
# RM_Name                   False
# Jr.RM_Name                False
# DL_Agency_Name            False
# TL_Agency_Name            False
# 2019-01-01 00:00:00        True
# 2019-02-01 00:00:00        True
# 2019-03-01 00:00:00        True
# 2019-04-01 00:00:00        True
# 2019-05-01 00:00:00        True
# 2019-06-01 00:00:00        True
# 2019-07-01 00:00:00        True
# 2019-08-01 00:00:00        True
# 2019-09-01 00:00:00        True
# 2019-10-01 00:00:00       False
# 2019-11-01 00:00:00       False
# 2019-12-01 00:00:00        True
# Total Sale 2019           False
# Total Business in 2019    False
# 2020-01-01 00:00:00       False
# ...

# %%
c.isnull()
# Out:
#       Client_Code  Client_Code.1  Address   City  Taluka  District    Pin  \
# 0           False          False    False  False   False     False  False
# 1           False          False    False  False   False     False  False
# 2           False          False    False  False   False     False  False
# 3           False          False    False  False   False     False  False
# 4           False          False    False  False   False     False  False
# ...           ...            ...      ...    ...     ...       ...    ...
# 3297        False          False    False  False   False     False  False
# 3298        False          False    False  False   False     False  False
# 3299        False          False    False  False   False     False  False
# 3300        False          False    False  False   False     False  False
# 3301        False          False    False  False   False     False  False
#
#       Product_Name  Area Type  Division  ...  2021-05-01 00:00:00  \
# ...

# %%
c.isnull().sum()
# Out:
# Client_Code                  0
# Client_Code.1                0
# Address                      0
# City                        13
# Taluka                       0
# District                     0
# Pin                          0
# Product_Name                 0
# Area Type                    0
# Division                     0
# RM_Name                      0
# Jr.RM_Name                   0
# DL_Agency_Name               0
# TL_Agency_Name               0
# 2019-01-01 00:00:00        818
# 2019-02-01 00:00:00       1460
# 2019-03-01 00:00:00        985
# 2019-04-01 00:00:00        176
# 2019-05-01 00:00:00        709
# 2019-06-01 00:00:00       1261
# 2019-07-01 00:00:00        486
# 2019-08-01 00:00:00        536
# 2019-09-01 00:00:00        657
# 2019-10-01 00:00:00          0
# 2019-11-01 00:00:00          0
# 2019-12-01 00:00:00        454
# Total Sale 2019              0
# Total Business in 2019       0
# 2020-01-01 00:00:00          0
# 2020-02-01 00:00:00          0
# ...

# %%
c.columns
# Out:
# Index([           'Client_Code',          'Client_Code.1',
#                       'Address',                   'City',
#                        'Taluka',               'District',
#                           'Pin',           'Product_Name',
#                     'Area Type',               'Division',
#                       'RM_Name',             'Jr.RM_Name',
#                'DL_Agency_Name',         'TL_Agency_Name',
#             2019-01-01 00:00:00,      2019-02-01 00:00:00,
#             2019-03-01 00:00:00,      2019-04-01 00:00:00,
#             2019-05-01 00:00:00,      2019-06-01 00:00:00,
#             2019-07-01 00:00:00,      2019-08-01 00:00:00,
#             2019-09-01 00:00:00,      2019-10-01 00:00:00,
#             2019-11-01 00:00:00,      2019-12-01 00:00:00,
#               'Total Sale 2019', 'Total Business in 2019',
#             2020-01-01 00:00:00,      2020-02-01 00:00:00,
#             2020-03-01 00:00:00,      2020-04-01 00:00:00,
# ...

# %%
c.nsmallest(2,'Total Business in 2021')
# Out:
#      Client_Code                  Client_Code.1  \
# 1434    48210121       GULAB COMPUTER EDUCATION
# 376     45210179  SHREE COMPUTER CENTER KILLARI
#
#                                                 Address     City  Taluka  \
# 1434  PLOT NO. 25,ROOM NO. B-22 RATNADEEP CO-OP HSG....   MUMBAI  Mumbai
# 376                                     At Post Killari  Killari    Ausa
#
#                     District     Pin Product_Name Area Type  \
# 1434  Mumbai Western Suburbs  400101   Quick heal     Urban
# 376                    Latur  413516   Quick heal     Rural
#
#                  Division  ... 2021-05-01 00:00:00 2021-06-01 00:00:00  \
# 1434       Kokan Division  ...                   0                   0
# 376   Aurangabad Division  ...                   3                   0
#
#      2021-07-01 00:00:00 2021-08-01 00:00:00  2021-09-01 00:00:00  \
# 1434                   0                   0                    0
# ...

# %%
c.nlargest(2,'Total Business in 2021')
# Out:
#     Client_Code    Client_Code.1  \
# 218    39210019   Asian Infotech
# 282    25210019  Excel Computers
#
#                                                Address     City   Taluka  \
# 218  Rameshwar Complex, D Wing, Flat No 3, Bharad, ...   Malvan   Malvan
# 282  New Mondha, Near Gopal Lodge,Beside Shri Agrse...  Hingoli  Hingoli
#
#        District     Pin Product_Name Area Type             Division  ...  \
# 218  Sindhudurg  416606   Quick heal     Urban       Kokan Division  ...
# 282     Hingoli  431513   Quick heal     Urban  Aurangabad Division  ...
#
#     2021-05-01 00:00:00 2021-06-01 00:00:00 2021-07-01 00:00:00  \
# 218                  93                 115                 112
# 282                 147                 149                 101
#
#     2021-08-01 00:00:00  2021-09-01 00:00:00  2021-10-01 00:00:00  \
# 218                  59                   47                   41
# 282                 107                  118                  101
#
# ...

# %%
c.sort_values(by='Total Business in 2021' , ascending=True)
# Out:
#      Client_Code                              Client_Code.1  \
# 1434    48210121                   GULAB COMPUTER EDUCATION
# 1312    58210004                  KEERTI COMPUTER INSTITUTE
# 1612    78210362                    Impact Computer Academy
# 436     35210022                      Pace Computer Academy
# 376     45210179              SHREE COMPUTER CENTER KILLARI
# ...          ...                                        ...
# 26      19210059  Shahu Institute Of Information Technology
# 685     16210102                              Sim Computers
# 4       19210010                          Webtech Computers
# 282     25210019                            Excel Computers
# 218     39210019                             Asian Infotech
#
#                                                 Address            City  \
# 1434  PLOT NO. 25,ROOM NO. B-22 RATNADEEP CO-OP HSG....          MUMBAI
# 1312  Keerti Computer Institute, 173/9, Talav Co-op ...          Mumbai
# ...

# %%
c[c['Total Business in 2021']>2222][:5]
# Out:
#    Client_Code                         Client_Code.1  \
# 0  Client_Code     Essay Infotech Computer Institute
# 1     19210002  Mark Computer Information Technology
# 2     19210004         Sharmeen`S Computer Education
# 3     19210007                          Om Computers
# 4     19210010                     Webtech Computers
#
#                                              Address            City  \
# 0             Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1  1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2          Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# 3  Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sa...        Poladpur
# 4  120,First Floor, Riddhi Complex, Sector-13, Kh...  New Panvel (W)
#
#      Taluka District     Pin Product_Name Area Type        Division  ...  \
# 0    Panvel   Raigad  410218   Quick heal     Urban  Kokan Division  ...
# 1     Mahad   Raigad  402301   Quick heal     Urban  Kokan Division  ...
# ...

# %%
c['Total Business in 2021'].unique()
# Out:
# array([ 70000,  99500,  30750,  58500, 280500,  26000,  30250,  61000,
#         68000,  28500,  85750,  28750,  25500,  47500,  11500, 109250,
#         51500,  40500,  49500,  16250,  30000,  22250, 133750,  35000,
#         21250, 244750,  80000,  55750,  66500,  64500,  78250, 113500,
#        191000,  83500,  73500,  87000,  76500,  77500,  52500,  96250,
#         60000,  29750,  55250,  20250,  63000,  36000, 147000,  37250,
#         31500, 125750,  21500, 241500,  14000,  56000, 141750,  82500,
#         62250, 225250, 106500, 225500,  61250, 129750, 204250, 102000,
#         41750,  27000,  32750,  28000,  29250,  27750,  31000,  16000,
#         12500,  47250,  69500,  93000, 131500, 100000, 102500,  66000,
#         10000,  59500,  75500,  10750, 146250,  37500, 162250,  38000,
#        130250, 126500,  86750, 112500,  30500, 138250,  70250,  88250,
#         95500,  69750,  65500,  60750,  57250,  18500,  56500,  79250,
# ...

# %%
c.memory_usage()
# Out:
# Index                       128
# Client_Code               26416
# Client_Code.1             26416
# Address                   26416
# City                      26416
# Taluka                    26416
# District                  26416
# Pin                       26416
# Product_Name              26416
# Area Type                 26416
# Division                  26416
# RM_Name                   26416
# Jr.RM_Name                26416
# DL_Agency_Name            26416
# TL_Agency_Name            26416
# 2019-01-01 00:00:00       26416
# 2019-02-01 00:00:00       26416
# 2019-03-01 00:00:00       26416
# 2019-04-01 00:00:00       26416
# 2019-05-01 00:00:00       26416
# 2019-06-01 00:00:00       26416
# 2019-07-01 00:00:00       26416
# 2019-08-01 00:00:00       26416
# 2019-09-01 00:00:00       26416
# 2019-10-01 00:00:00       26416
# 2019-11-01 00:00:00       26416
# 2019-12-01 00:00:00       26416
# Total Sale 2019           26416
# Total Business in 2019    26416
# ...

# %%
import sqlite3

# %%
conn=sqlite3.connect('data.db')

# %%
df=pd.read_sql('select * FROM tablename', conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pandas\io\sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# OperationalError: near "table": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In [86], line 1
# ----> 1 df=pd.read_sql('select * FROM table', conn)
#
# File ~\miniconda3\lib\site-packages\pandas\io\sql.py:564, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     561 pandas_sql = pandasSQL_builder(con)
#     563 if isinstance(pandas_sql, SQLiteDatabase):
# --> 564     return pandas_sql.read_query(
#     565         sql,
#     566         index_col=index_col,
# ...

# %%
pd.DataFrame(c)
# Out:
#       Client_Code                         Client_Code.1  \
# 0     Client_Code     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
p
# Out:
#     name  age class     mobile
# 0  mohan   12   5th  876543456
# 1   rama   13   6th   98738765
# 2   sham   14   7th  987675432

# %%
p.insert(1,'sal',[44444,6666,8888])

# %%
p
# Out:
#     name    sal  age class     mobile
# 0  mohan  44444   12   5th  876543456
# 1   rama   6666   13   6th   98738765
# 2   sham   8888   14   7th  987675432

# %%
p.loc[3]=[888,'7777777',45,'7777',876543]

# %%
p
# Out:
#     name      sal  age class     mobile
# 0  mohan    44444   12   5th  876543456
# 1   rama     6666   13   6th   98738765
# 2   sham     8888   14   7th  987675432
# 3    888  7777777   45  7777     876543

# %%
p=p.append(pd.Series(['krish',76543,6,'1th',987654], index=['name','sal','age','class','mobile']),ignore_index=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2084\2091439322.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p=p.append(pd.Series(['krish',76543,6,'1th',987654], index=['name','sal','age','class','mobile']),ignore_index=True)

# %%
p=p.append(pd.Series(['krish1',76543765,9,'3th',98767654], index=p.columns),ignore_index=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_2084\3313750206.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   p=p.append(pd.Series(['krish1',76543765,9,'3th',98767654], index=p.columns),ignore_index=True)

# %%
p
# Out:
#      name       sal  age class     mobile
# 0   mohan     44444   12   5th  876543456
# 1    rama      6666   13   6th   98738765
# 2    sham      8888   14   7th  987675432
# 3     888   7777777   45  7777     876543
# 4  krish1  76543765    9   3th   98767654
# 5   krish     76543    6   1th     987654

# %%
c=p.set_index('name')

# %%
c
# Out:
#              sal  age class     mobile
# name
# mohan      44444   12   5th  876543456
# rama        6666   13   6th   98738765
# sham        8888   14   7th  987675432
# 888      7777777   45  7777     876543
# krish1  76543765    9   3th   98767654
# krish      76543    6   1th     987654

# %%
c=p.set_index(['name','sal'])  # set multiple column as index

# %%
c
# Out:
#                  age class     mobile
# name   sal
# mohan  44444      12   5th  876543456
# rama   6666       13   6th   98738765
# sham   8888       14   7th  987675432
# 888    7777777    45  7777     876543
# krish1 76543765    9   3th   98767654
# krish  76543       6   1th     987654

# %%
c={
    'id':[1,2,3,4,5],
    'sal':[987654,543256,2345678,89765433,89765433]
}

# %%
c=pd.DataFrame(c)

# %%
c
# Out:
#    id       sal
# 0   1    987654
# 1   2    543256
# 2   3   2345678
# 3   4  89765433
# 4   5  89765433

# %%
c.idxmax(axis=0)
# Out:
# id     4
# sal    3
# dtype: int64

# %%
c.idxmin(axis=0)
# Out:
# id     0
# sal    1
# dtype: int64

# %%
df=pd.DataFrame({"A":[4,5,2,6],'B':[11,2,5,8],"c":[1,8,66,4]})

# %%
df
# Out:
#    A   B   c
# 0  4  11   1
# 1  5   2   8
# 2  2   5  66
# 3  6   8   4

# %%
df.idxmax(axis=0)
# Out:
# A    3
# B    0
# c    2
# dtype: int64

# %%
df['A'].idxmax()
# Out:
# 3
