# %%
import pandas as pd

# %%
id oper 
id oper 
all oper nahit
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10196\808649497.py", line 1
#     id oper
#        ^
# SyntaxError: invalid syntax

# %%
table1[table1['oper'] in set(table1['oper']).difference(set(table2['oper']))]

df1[df1['oper'] not in df2['oper']][['oper']]

# %%
df=pd.read_excel(r"C:\ML\Data_final_pivot_table.xlsx") 
df
# Out:
#       Client_Code                           Client_Name  \
# 0        19210001     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
# df[df['Taluka']=='Kalamb'][['City','District']]
# df[df['Taluka']=='Kalamb'][['City']]
df[df['Taluka']=='Kalamb']
# Out:
#       Client_Code                        Client_Name  \
# 1090     36210025                 New Cyber Infotech
# 1096     36210031                  Gayatri Computers
# 1100     36210038         Ap-Tech Computer Education
# 1107     36210064                Aashirwad Computers
# 1108     36210070                  Gayatri Computers
# 1118     36210104         HI-TECH COMPUTER EDUCATION
# 1119     36210106  SAI COLLEGE OF COMPUTER EDUCATION
# 1125     36210122                       SAI COMPUTER
# 1129     36210131   Shree Samarth Computer Education
# 1160     36210205                    SATYAM COMPUTER
# 1161     36210206             Prachi computer center
# 1162     36210207                Shreeyesh Computers
# 3273     42210062              Shubham Computer Ins.
# 3301     42210132           IMAGE COMPUTER EDUCATION
#
#                                                 Address        City  Taluka  \
# 1090           shivaji chowk parli road opp bsnl office      Kalamb  Kalamb
# ...

# %%
# city = alibaag and total salary between 500-100
df[(df['City']=='Alibag') & ((df['Total Sale 2021']>=500) & (df['Total Sale 2021']<=1000 ))]
# Out:
#     Client_Code                       Client_Name  \
# 57     19210147  CREATIVE TECH COMPUTER EDUCATION
#
#                                               Address    City  Taluka  \
# 57  Near Kanyashala, Brahmin Ali, Alibag, Dist Raigad  Alibag  Alibag
#
#    District     Pin Product_Name Area Type        Division  ...  \
# 57   Raigad  402201   Quick heal     Urban  Kokan Division  ...
#
#    2021-05-01 00:00:00 2021-06-01 00:00:00 2021-07-01 00:00:00  \
# 57                  17                  41                   1
#
#    2021-08-01 00:00:00  2021-09-01 00:00:00  2021-10-01 00:00:00  \
# 57                   0                   10                    0
#
#     2021-11-01 00:00:00  2021-12-01 00:00:00 Total Sale 2021  \
# 57                   93                   35             567
#
#     Total Business in 2021
# 57                  141750
#
# [1 rows x 56 columns]

# %%
gb=df.groupby(df['City'])
gb.mean('Total Business in 2021')[['Total Business in 2021']]
# Out:
#                Total Business in 2021
# City
# ADAS                          28500.0
# ADUL                         104500.0
# AHMEDPUR                       7500.0
# AJINTHA                      121500.0
# AKOLA                         37450.0
# ...                               ...
# umapur                        20250.0
# uruli kanchan                 47500.0
# vaijapur                      26500.0
# wadwani                       86500.0
# yavatmal                      74500.0
#
# [1450 rows x 1 columns]

# %%
gb=df.groupby(['City','District'])
gb.mean()
# Out:
#                           Client_Code       Pin  2019-01-01 00:00:00  \
# City          District
# ADAS          Beed         46210304.0  431517.0             5.000000
# ADUL          Aurangabad   16210226.0  431121.0                  NaN
# AHMEDPUR      Latur        45210168.0  413515.0            12.000000
# AJINTHA       Aurangabad   16210293.0  431117.0                  NaN
# AKOLA         Akola        12210107.4  444002.0             7.333333
# ...                               ...       ...                  ...
# umapur        Beed         46210313.0  431130.0                  NaN
# uruli kanchan Pune South   47210104.0  412202.0            43.000000
# vaijapur      Aurangabad   16210315.0  423701.0             9.000000
# wadwani       Beed         46210245.0  431144.0            17.000000
# yavatmal      Yavatmal     42210126.0  445001.0                  NaN
#
#                           2019-02-01 00:00:00  2019-03-01 00:00:00  \
# City          District
# ...

# %%
c=c.dropna()
obj=c.groupby(c['City'])
for i in c['City'].unique():
    print(i,'      -->',obj.get_group(f"{i}")['Total Sale 2021'].mean())
# Out:
# Mahad       --> 302.0
# New Panvel (W)       --> 1122.0
# Roha       --> 171.0
# Panvel       --> 405.3333333333333
# Revdanda       --> 272.0
# KHOPOLI       --> 343.0
# Navi Mumbai       --> 535.0
# Murud       --> 348.0
# Karjat       --> 319.6666666666667
# Nagothane       --> 149.0
# Kalamboli       --> 503.0
# Kamothe       --> 410.0
# PEN       --> 43.0
# CHANERE       --> 353.0
# KAMOTHE       --> 226.0
# Bhira       --> 201.0
# TALA       --> 151.0
# Chiplun       --> 559.0
# Lanja       --> 109.0
# Rajapur       --> 241.0
# Mandangad       --> 135.0
# Nachane       --> 133.0
# Kuwarbav       --> 257.0
# Shringartali       --> 119.0
# Adiware       --> 130.0
# PIR LOTE       --> 385.0
# Dapoli       --> 229.0
# Devrukh       --> 317.0
# NATE       --> 280.0
# Sawarde       --> 641.0
# DEVHARE       --> 41.0
# CHIPLUN       --> 178.0
# Kotawade       --> 242.0
# Sakharpa (Kondgaon)       --> 136.0
# Kudal       --> 190.5
# Katta       --> 130.0
# sawantwadi       --> 150.0
# ...

# %%
obj=c.groupby('City')
obj.mean('Total Sale 2021')[['Total Sale 2021']]
# Out:
#                Total Sale 2021
# City
# ADAS                     114.0
# ADUL                     418.0
# AHMEDPUR                  30.0
# AJINTHA                  486.0
# AKOLA                    149.8
# ...                        ...
# umapur                    81.0
# uruli kanchan            190.0
# vaijapur                 106.0
# wadwani                  346.0
# yavatmal                 298.0
#
# [1450 rows x 1 columns]

# %%
df.groupby('Name').mean()
obj=c.groupby('City')
obj.max('Total Sale 2021')[['Total Sale 2021']]
# Out:
#                Total Sale 2021
# City
# ADAS                       114
# ADUL                       418
# AHMEDPUR                    30
# AJINTHA                    486
# AKOLA                      233
# ...                        ...
# umapur                      81
# uruli kanchan              190
# vaijapur                   106
# wadwani                    346
# yavatmal                   298
#
# [1450 rows x 1 columns]

# %%
df.sample()
# Out:
#       Client_Code             Client_Name  \
# 2226     37210018  Sun Computer Education
#
#                                                 Address  City  Taluka  \
# 2226  SUN COMPUTER EDUCATION , FLAT NO 8, SHANTI PRE...  Pune  Haveli
#
#         District     Pin Product_Name Area Type       Division  ...  \
# 2226  Pune South  411041   Quick heal     Urban  Pune Division  ...
#
#      2021-05-01 00:00:00 2021-06-01 00:00:00 2021-07-01 00:00:00  \
# 2226                  26                   0                  35
#
#      2021-08-01 00:00:00  2021-09-01 00:00:00  2021-10-01 00:00:00  \
# 2226                   0                   38                    0
#
#       2021-11-01 00:00:00  2021-12-01 00:00:00 Total Sale 2021  \
# 2226                   28                    0             292
#
#       Total Business in 2021
# 2226                   73000
#
# [1 rows x 56 columns]

# %%
df.head(5)
# Out:
#    Client_Code                           Client_Name  \
# 0     19210001     Essay Infotech Computer Institute
# 1     19210002  Mark Computer Information Technology
# 2     19210004         Sharmeen`S Computer Education
# 3     19210007                          Om Computers
# 4     19210010                     Webtech Computers
#
#                                              Address            City  \
# 0             Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1  1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2          Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# 3  Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sa...        Poladpur
# 4  120,First Floor, Riddhi Complex, Sector-13, Kh...  New Panvel (W)
#
#      Taluka District     Pin Product_Name Area Type        Division  ...  \
# 0    Panvel   Raigad  410218   Quick heal     Urban  Kokan Division  ...
# 1     Mahad   Raigad  402301   Quick heal     Urban  Kokan Division  ...
# ...

# %%
df.tail()
# Out:
#       Client_Code                    Client_Name  \
# 3297     42210125              Jalaram Computers
# 3298     42210126                  sai computers
# 3299     42210127  Good-Luck Computers, Maregaon
# 3300     42210128      SUYASH COMPUTER INSTITUTE
# 3301     42210132       IMAGE COMPUTER EDUCATION
#
#                                                 Address      City    Taluka  \
# 3297  Paltewar Complex, Near Dr. Puranik Hospital,Ma...  Ghatanji  Ghatanji
# 3298  vishal nagar,pipalgaon yawatmal, vishal nagar,...  yavatmal  Yavatmal
# 3299  At Po Maregaon, At Po Maregaon, At Po Maregaon...  Maregaon  Maregaon
# 3300  SUYASH SADAN, MAIN ROAD GHATANJI TQ.GHATANJI, ...  GHATANJI  Ghatanji
# 3301       Near Indira Chowk, Halbipura, Kalamb, Kalamb    KALAMB    Kalamb
#
#       District     Pin Product_Name Area Type           Division  ...  \
# 3297  Yavatmal  445301   Quick heal     Urban  Amravati Division  ...
# ...

# %%
#df.isnull().sum().sum()  # to count total null in df
df.isnull().sum()   # columnwise null
# Out:
# Client_Code                  0
# Client_Name                  0
# Address                      0
# City                        13
# Taluka                       0
# District                     0
# Pin                          0
# Product_Name                 0
# Area Type                    0
# Division                     0
# RM_Name                      0
# Jr.RM_Name                   0
# DL_Agency_Name               0
# TL_Agency_Name               0
# 2019-01-01 00:00:00        818
# 2019-02-01 00:00:00       1460
# 2019-03-01 00:00:00        985
# 2019-04-01 00:00:00        176
# 2019-05-01 00:00:00        709
# 2019-06-01 00:00:00       1261
# 2019-07-01 00:00:00        486
# 2019-08-01 00:00:00        536
# 2019-09-01 00:00:00        657
# 2019-10-01 00:00:00          0
# 2019-11-01 00:00:00          0
# 2019-12-01 00:00:00        454
# Total Sale 2019              0
# Total Business in 2019       0
# 2020-01-01 00:00:00          0
# 2020-02-01 00:00:00          0
# ...

# %%
df.shape
# Out:
# (3302, 56)

# %%
new_df = df.set_index('Client_Code')
new_df
# Out:
#                                       Client_Name  \
# Client_Code
# 19210001        Essay Infotech Computer Institute
# 19210002     Mark Computer Information Technology
# 19210004            Sharmeen`S Computer Education
# 19210007                             Om Computers
# 19210010                        Webtech Computers
# ...                                           ...
# 42210125                        Jalaram Computers
# 42210126                            sai computers
# 42210127            Good-Luck Computers, Maregaon
# 42210128                SUYASH COMPUTER INSTITUTE
# 42210132                 IMAGE COMPUTER EDUCATION
#
#                                                        Address  \
# Client_Code
# 19210001                Angel Arc,Shop No.13,Plot No-23,Sec-8,
# 19210002     1/3, Ashiana Complex, Shivaji Road, Near Hotel...
# 19210004             Plot R-14 Shreebaug, No 3, Near Bus Stand
# 19210007     Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sa...
# ...

# %%
ndf=df.reindex(df['Address'])
ndf
# Out:
#                                                     Client_Code Client_Name  \
# Address
# Angel Arc,Shop No.13,Plot No-23,Sec-8,                      NaN         NaN
# 1/3, Ashiana Complex, Shivaji Road, Near Hotel ...          NaN         NaN
# Plot R-14 Shreebaug, No 3, Near Bus Stand                   NaN         NaN
# Subhadra Kunj, Shop No. 7, Old ITI Bulding, Sai...          NaN         NaN
# 120,First Floor, Riddhi Complex, Sector-13, Kha...          NaN         NaN
# ...                                                         ...         ...
# Paltewar Complex, Near Dr. Puranik Hospital,Mai...          NaN         NaN
# vishal nagar,pipalgaon yawatmal, vishal nagar,p...          NaN         NaN
# At Po Maregaon, At Po Maregaon, At Po Maregaon,...          NaN         NaN
# SUYASH SADAN, MAIN ROAD GHATANJI TQ.GHATANJI, D...          NaN         NaN
# Near Indira Chowk, Halbipura, Kalamb, Kalamb                NaN         NaN
#
# ...

# %%
df['City'].unique()   # uniqe values
len(df['City'].unique())  # no of unique city
# Out:
# 1451

# %%
df['City'].value_counts()   # count of each city
# Out:
# Mumbai           152
# Pune             106
# Aurangabad        73
# Nagpur            67
# Nashik            55
#                 ...
# WORLI NAKA         1
# Wadala Mumbai      1
# Malgund            1
# Ghatkopar - E      1
# KALAMB             1
# Name: City, Length: 1450, dtype: int64

# %%
df.sort_values(by=df.columns.to_list(),ascending=False)  # every col desceding
df.sort_values(by=['Client_Code'],ascending=False)    # one col desc
# Out:
#       Client_Code                              Client_Name  \
# 1461    108210048                          PRIME COMPUTERS
# 1460    108210046                       MiC SOFT SOLUTIONS
# 1459    108210044                         SHAMAL COMPUTERS
# 1458    108210042                   smart computer academy
# 1457    108210041                Keerti Computer Institute
# ...           ...                                      ...
# 1678     11210027                             Aim Computer
# 1677     11210018  Modern Institute Of Computer Technology
# 1676     11210014                 Yash Computer Technology
# 1675     11210013       Pioneer Computer Technology Center
# 1674     11210003                   IGM Computer Education
#
#                                                 Address     City    Taluka  \
# 1461  SHOP NO A-5 , ANDHERI CHAYA, SRA CHS LTD, OPP ...      NaN   Andheri
# 1460  micsoft solutions, near srpf camp group 8, wes...   MUMBAI   Andheri
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10196\2201091848.py in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.query('Taluka == "Kalamb" or Taluka == "Andheri"')
# df.query('            ')
# Out:
#       Client_Code                 Client_Name  \
# 1090     36210025          New Cyber Infotech
# 1096     36210031           Gayatri Computers
# 1100     36210038  Ap-Tech Computer Education
# 1107     36210064         Aashirwad Computers
# 1108     36210070           Gayatri Computers
# ...           ...                         ...
# 1457    108210041   Keerti Computer Institute
# 1460    108210046          MiC SOFT SOLUTIONS
# 1461    108210048             PRIME COMPUTERS
# 3273     42210062       Shubham Computer Ins.
# 3301     42210132    IMAGE COMPUTER EDUCATION
#
#                                                 Address       City   Taluka  \
# 1090           shivaji chowk parli road opp bsnl office     Kalamb   Kalamb
# 1096  GANDHI NAGAR, GANDHI CHOWK, BAZAR MAIDAN ROAD,...     Kalamb   Kalamb
# 1100                                Near Rural Hospital     Kalamb   Kalamb
# 1107   Opp. Police Station, Barshi Road At.Post.Yermala    Yermala   Kalamb
# ...

# %%
data = {
    'Name': ['John', 'Matt', 'John', 'Cateline'],
    'math_Marks': [18, 20, 19, 15],
    'science_Marks': [10, 20, 15, 12]
}

# Create a DataFrame df
df = pd.DataFrame(data)

df['total'] = df.apply(lambda row : row["math_Marks"] + row["science_Marks"], axis=1)


print(df)
# Out:
#        Name  math_Marks  science_Marks  total
# 0      John          18             10     28
# 1      Matt          20             20     40
# 2      John          19             15     34
# 3  Cateline          15             12     27

# %%
df['total1'] = df["math_Marks"] + df["science_Marks"]

# %%
df
# Out:
#        Name  math_Marks  science_Marks  total  total1
# 0      John          18             10     28      28
# 1      Matt          20             20     40      40
# 2      John          19             15     34      34
# 3  Cateline          15             12     27      27

# %%
# to handle null values
interpolate() – this method fills the missing values with computed interpolation values. 
The interpolation technique can be linear, polynomial, spline, time, etc.,
