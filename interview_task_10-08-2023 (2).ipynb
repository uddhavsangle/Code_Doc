# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_excel('diabetes_data.xlsx')

# %%
df1 = df.copy()

# %%
df1.drop(['encounter_id', 'patient_nbr', 'id'], axis=1, inplace=True)

# %%
df1
# Out:
#                    race  gender      age weight  admission_type_id  \
# 0             Caucasian  Female   [0-10)      ?                  6
# 1             Caucasian  Female  [10-20)      ?                  1
# 2       AfricanAmerican  Female  [20-30)      ?                  1
# 3             Caucasian    Male  [30-40)      ?                  1
# 4             Caucasian    Male  [40-50)      ?                  1
# ...                 ...     ...      ...    ...                ...
# 101761  AfricanAmerican    Male  [70-80)      ?                  1
# 101762  AfricanAmerican  Female  [80-90)      ?                  1
# 101763        Caucasian    Male  [70-80)      ?                  1
# 101764        Caucasian  Female  [80-90)      ?                  2
# 101765        Caucasian    Male  [70-80)      ?                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                             25                    1                 1
# ...

# %%
df1.columns
# Out:
# Index(['race', 'gender', 'age', 'weight', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'payer_code', 'medical_specialty', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3',
#        'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide.metformin', 'glipizide.metformin',
#        'glimepiride.pioglitazone', 'metformin.rosiglitazone',
#        'metformin.pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
sns.heatmap(df1.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %%
df1.isnull().sum()
# Out:
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# ...

# %%
for i in df1.columns:
    df1[i] = df1[i].map(lambda x: x if x!='?' else None)

# %%
df1
# Out:
#                    race  gender      age weight  admission_type_id  \
# 0             Caucasian  Female   [0-10)   None                  6
# 1             Caucasian  Female  [10-20)   None                  1
# 2       AfricanAmerican  Female  [20-30)   None                  1
# 3             Caucasian    Male  [30-40)   None                  1
# 4             Caucasian    Male  [40-50)   None                  1
# ...                 ...     ...      ...    ...                ...
# 101761  AfricanAmerican    Male  [70-80)   None                  1
# 101762  AfricanAmerican  Female  [80-90)   None                  1
# 101763        Caucasian    Male  [70-80)   None                  1
# 101764        Caucasian  Female  [80-90)   None                  2
# 101765        Caucasian    Male  [70-80)   None                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                             25                    1                 1
# ...

# %%
df1.isnull().sum()
# Out:
# race                         2273
# gender                          0
# age                             0
# weight                      98569
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  40256
# medical_specialty           49949
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         21
# diag_2                        358
# diag_3                       1423
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# chlorpropamide                  0
# glimepiride                     0
# ...

# %%
df1.drop(['weight'], axis=1, inplace=True)

# %%
df1.isnull().sum()
# Out:
# race                        2273
# gender                         0
# age                            0
# admission_type_id              0
# discharge_disposition_id       0
# admission_source_id            0
# time_in_hospital               0
# num_lab_procedures             0
# num_procedures                 0
# num_medications                0
# number_outpatient              0
# number_emergency               0
# number_inpatient               0
# diag_1                        21
# diag_2                       358
# diag_3                      1423
# number_diagnoses               0
# max_glu_serum                  0
# A1Cresult                      0
# metformin                      0
# repaglinide                    0
# nateglinide                    0
# chlorpropamide                 0
# glimepiride                    0
# acetohexamide                  0
# glipizide                      0
# glyburide                      0
# tolbutamide                    0
# ...

# %%
df1.drop(['payer_code', 'medical_specialty'], axis =1, inplace = True)

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# acarbose                    0
# ...

# %%
for i in de.columns:
    print(i.unique())
# Out:
# (98053, 45)

# %%
# Out:
#                    race  gender      age  admission_type_id  \
# 1             Caucasian  Female  [10-20)                  1
# 2       AfricanAmerican  Female  [20-30)                  1
# 3             Caucasian    Male  [30-40)                  1
# 4             Caucasian    Male  [40-50)                  1
# 5             Caucasian    Male  [50-60)                  2
# ...                 ...     ...      ...                ...
# 101761  AfricanAmerican    Male  [70-80)                  1
# 101762  AfricanAmerican  Female  [80-90)                  1
# 101763        Caucasian    Male  [70-80)                  1
# 101764        Caucasian  Female  [80-90)                  2
# 101765        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# 1                              1                    7                 3
# 2                              1                    7                 2
# ...

# %%
sns.boxplot(df['num_lab_procedures'])
# Out:
# C:\Users\deshm\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_lab_procedures'>

# %%
from sklearn.preprocessing import LabelEncoder
for i in df1.columns:
    if df1[i].dtype != int and len(df1[i].unique())<10:
#         print(i, [j for j in df1[i].unique()])
#         obj = OrdinalEncoder(categories=[j for j in df1[i].unique()])
        obj = LabelEncoder()
        df1[f'{i}_new'] = obj.fit(df1[[i]]).transform(df1[[i]])
        df1.drop([i], axis=1, inplace= True)
# Out:
# C:\Users\deshm\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\deshm\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:134: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# C:\Users\deshm\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:99: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
[j for j in df1['gender'].unique()]
# Out:
# ['Female', 'Male', 'Unknown/Invalid']

# %%
df1.corr()
# Out:
#                               discharge_disposition_id  admission_source_id  \
# discharge_disposition_id                      1.000000             0.016532
# admission_source_id                           0.016532             1.000000
# time_in_hospital                              0.162907            -0.007975
# num_lab_procedures                            0.022610             0.048061
# num_medications                               0.106692            -0.055741
# number_outpatient                            -0.010277             0.025307
# number_emergency                             -0.025988             0.059001
# number_inpatient                              0.019039             0.035541
# number_diagnoses                              0.038427             0.071770
# race_new                                     -0.007997             0.021326
# gender_new                                   -0.020881            -0.004019
# ...

# %%
df1.drop(['examide_new', 'citoglipton_new', 'metformin.rosiglitazone_new'], axis=1, inplace=True)

# %%
df1.corr()
# Out:
#                               discharge_disposition_id  admission_source_id  \
# discharge_disposition_id                      1.000000             0.016532
# admission_source_id                           0.016532             1.000000
# time_in_hospital                              0.162907            -0.007975
# num_lab_procedures                            0.022610             0.048061
# num_medications                               0.106692            -0.055741
# number_outpatient                            -0.010277             0.025307
# number_emergency                             -0.025988             0.059001
# number_inpatient                              0.019039             0.035541
# number_diagnoses                              0.038427             0.071770
# race_new                                     -0.007997             0.021326
# gender_new                                   -0.020881            -0.004019
# ...
